# %%
using CSV
using DataFrames
using DataFramesMeta
using Statistics
using FreqTables
using CategoricalArrays

# %%
a1=DataFrame(CSV.File("./csv/asts.csv"))
# Out:
# 24×2 DataFrame
#  Row │ asts     tla
#      │ String7  String3
# ─────┼──────────────────
#    1 │ fvxa     KVH
#    2 │ yqoq     EKS
#    3 │ fvxa     GSA
#    4 │ yqoq     MSN
#    5 │ cdlm     JPS
#    6 │ eion     CTA
#    7 │ qmvi     EAG
#    8 │ veiy     HOL
#    9 │ oexk     DBA
#   10 │ tfov     DOS
#   11 │ dduv     HGG
#   ⋮  │    ⋮        ⋮
#   15 │ lett     MFB
#   16 │ xfqk     CTC
#   17 │ prif     MFD
#   18 │ bosg     BUT
#   19 │ xega     VGL
#   20 │ obye     BAR
#   21 │ xxol     OMA
#   22 │ goag     OMB
#   23 │ kynz     KOL
#   24 │ aeyb     RSB
#           3 rows omitted

# %%
q1=DataFrame(CSV.File("./csv/quiz.csv"))
# Out:
# 1183×6 DataFrame
#   Row │ sc     ast      sdc     sno       ln          fn
#       │ Int64  String3  Int64   Int64     String15    String15
# ──────┼──────────────────────────────────────────────────────────
#     1 │     3  KVH      104618  53639084  Ma          Jenny
#     2 │     5  KVH      104891  21791843  Liu         Ryan
#     3 │     5  KVH      109220  47707195  Smith       Makyla
#     4 │     5  KVH      117939  62159470  Urban       Jessica ()
#     5 │     5  KVH      120912  46027488  Eng         Julie
#     6 │     3  KVH      123875  47130190  Morinaka    Kate
#     7 │     2  KVH      133826  32998205  Poon        Owen
#     8 │     4  KVH      136541  55693444  Stumborg    Esme
#     9 │     4  KVH      152692  81004772  Kaur        Kirin
#    10 │     5  KVH      159842  56710692  Duff        Allison
#    11 │     2  KVH      171109  59219527  Lister      Graeme
#   ⋮   │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
#  1174 │     5  MAD      586981  28761799  Dhillon     Simran
#  1175 │     5  MAD      159842  56710692  Duff        Allison
#  1176 │     4  MAD      854333  38426516  Kohan       Anthony
#  1177 │     3  MAD      655715  50217298  Lee         Spencer
#  1178 │     2  MAD      123875  47130190  Morinaka    Kate
#  1179 │     5  MAD      373901  48709159  Peiro       Milad
#  1180 │     5  MAD      480843  17009144  Wang        Sabrina
#  1181 │     5  MAD      599697  86591872  Wilson      Isabel
#  1182 │     5  MAD      868366  76082957  Zhu         Kaida
#  1183 │     4  MAD      374400  79235719  Cuddington  Eero
#                                                 1162 rows omitted

# %%
freqtable(q1[:,:sc])
# Out:
# 6-element Named Vector{Int64}
# Dim1  │
# ──────┼────
# 0     │  28
# 1     │  83
# 2     │ 156
# 3     │ 214
# 4     │ 278
# 5     │ 424

# %%
q2=q1[q1.sc .< 5,:] # filter out absences
# Out:
# 759×6 DataFrame
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼─────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     3  KVH      123875  47130190  Morinaka    Kate
#    3 │     2  KVH      133826  32998205  Poon        Owen
#    4 │     4  KVH      136541  55693444  Stumborg    Esme
#    5 │     4  KVH      152692  81004772  Kaur        Kirin
#    6 │     2  KVH      171109  59219527  Lister      Graeme
#    7 │     4  KVH      171477  78865573  Stampliaka  Caroline
#    8 │     4  KVH      214934  34099135  Zhao        Curtis
#    9 │     3  KVH      217056  48465041  Lee         Daniel
#   10 │     2  KVH      230494  22250328  Zeng        Sabrina
#   11 │     4  KVH      251974  22885628  Imura       Dennis
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
#  750 │     4  MAD      507497  22213623  Wong        Hui
#  751 │     4  MAD      769815  27610260  Ye          Ryan
#  752 │     1  MAD      230494  22250328  Zeng        Sabrina
#  753 │     3  MAD      488081  44818177  Zhang       Jiaxin
#  754 │     2  MAD      214934  34099135  Zhao        Curtis
#  755 │     3  MAD      377532  40747941  Zurkovic    Nicholas
#  756 │     4  MAD      854333  38426516  Kohan       Anthony
#  757 │     3  MAD      655715  50217298  Lee         Spencer
#  758 │     2  MAD      123875  47130190  Morinaka    Kate
#  759 │     4  MAD      374400  79235719  Cuddington  Eero
#                                                738 rows omitted

# %%
/(mean(q2[:,:sc]),4) # mean score
# Out:
# 0.7078392621870883

# %%
q2g=groupby(q2,:ast)
# Out:
# GroupedDataFrame with 13 groups based on key: ast
# First Group (69 rows): ast = "KVH"
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼─────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     3  KVH      123875  47130190  Morinaka    Kate
#    3 │     2  KVH      133826  32998205  Poon        Owen
#    4 │     4  KVH      136541  55693444  Stumborg    Esme
#    5 │     4  KVH      152692  81004772  Kaur        Kirin
#    6 │     2  KVH      171109  59219527  Lister      Graeme
#    7 │     4  KVH      171477  78865573  Stampliaka  Caroline
#    8 │     4  KVH      214934  34099135  Zhao        Curtis
#    9 │     3  KVH      217056  48465041  Lee         Daniel
#   10 │     2  KVH      230494  22250328  Zeng        Sabrina
#   11 │     4  KVH      251974  22885628  Imura       Dennis
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
#   59 │     2  KVH      782903  82091455  Cader       Sarah
#   60 │     3  KVH      805101  57844268  Penner      Madeleine
#   61 │     3  KVH      829577  27307339  Chen        Emily
#   62 │     2  KVH      837888  85615573  Uppal       Jacquelyn
#   63 │     2  KVH      844462  52491586  Johal       Kajol
#   64 │     4  KVH      854333  38426516  Kohan       Anthony
#   65 │     3  KVH      855762  31888431  Brown       Maya
#   66 │     4  KVH      904274  86002110  Sharma      Serena ()
#   67 │     3  KVH      911815  18496018  Schmitter   Cameron
#   68 │     4  KVH      962740  75790980  Huang       Andrew
#   69 │     4  KVH      975179  27397421  Asawa       Vaidehi
#                                                 47 rows omitted
# ⋮
# Last Group (48 rows): ast = "MAD"
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼────────────────────────────────────────────────────────────
#    1 │     2  MAD      758592  73627077  Anand       Shaurya Veer
#    2 │     4  MAD      408620  33241019  Beesley     Tabby
#    3 │     4  MAD      524203  97714976  Bienert     Bella
#    4 │     2  MAD      767173  19909522  Bobyn       Alex ()
#    5 │     2  MAD      329294  42623306  Boivin      Jack Thomas
#    6 │     1  MAD      782903  82091455  Cader       Sarah
#    7 │     4  MAD      685939  77049898  Chambers    Colby
#    8 │     1  MAD      829577  27307339  Chen        Emily
#    9 │     3  MAD      734042  30161814  Coutinho    Annika
#   10 │     1  MAD      252398  80437940  Daryani     Khushi
#   11 │     3  MAD      653801  37896917  Galang      Ryland
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮            ⋮
#   38 │     1  MAD      837888  85615573  Uppal       Jacquelyn
#   39 │     4  MAD      507497  22213623  Wong        Hui
#   40 │     4  MAD      769815  27610260  Ye          Ryan
#   41 │     1  MAD      230494  22250328  Zeng        Sabrina
#   42 │     3  MAD      488081  44818177  Zhang       Jiaxin
#   43 │     2  MAD      214934  34099135  Zhao        Curtis
#   44 │     3  MAD      377532  40747941  Zurkovic    Nicholas
#   45 │     4  MAD      854333  38426516  Kohan       Anthony
#   46 │     3  MAD      655715  50217298  Lee         Spencer
#   47 │     2  MAD      123875  47130190  Morinaka    Kate
#   48 │     4  MAD      374400  79235719  Cuddington  Eero
#                                                    26 rows omitted

# %%
q2
# Out:
# 759×6 DataFrame
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼─────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     3  KVH      123875  47130190  Morinaka    Kate
#    3 │     2  KVH      133826  32998205  Poon        Owen
#    4 │     4  KVH      136541  55693444  Stumborg    Esme
#    5 │     4  KVH      152692  81004772  Kaur        Kirin
#    6 │     2  KVH      171109  59219527  Lister      Graeme
#    7 │     4  KVH      171477  78865573  Stampliaka  Caroline
#    8 │     4  KVH      214934  34099135  Zhao        Curtis
#    9 │     3  KVH      217056  48465041  Lee         Daniel
#   10 │     2  KVH      230494  22250328  Zeng        Sabrina
#   11 │     4  KVH      251974  22885628  Imura       Dennis
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
#  750 │     4  MAD      507497  22213623  Wong        Hui
#  751 │     4  MAD      769815  27610260  Ye          Ryan
#  752 │     1  MAD      230494  22250328  Zeng        Sabrina
#  753 │     3  MAD      488081  44818177  Zhang       Jiaxin
#  754 │     2  MAD      214934  34099135  Zhao        Curtis
#  755 │     3  MAD      377532  40747941  Zurkovic    Nicholas
#  756 │     4  MAD      854333  38426516  Kohan       Anthony
#  757 │     3  MAD      655715  50217298  Lee         Spencer
#  758 │     2  MAD      123875  47130190  Morinaka    Kate
#  759 │     4  MAD      374400  79235719  Cuddington  Eero
#                                                738 rows omitted

# %%
q4=hcat(
ifelse.(q2[!,[:ast]].=="KVH","fvxa",
ifelse.(q2[!,[:ast]].=="EKS","yqoq",
ifelse.(q2[!,[:ast]].=="GSA","lqyc",
ifelse.(q2[!,[:ast]].=="MSN","jzck",
ifelse.(q2[!,[:ast]].=="JPS","cdlm",
ifelse.(q2[!,[:ast]].=="CTA","eion",
ifelse.(q2[!,[:ast]].=="EAG","qmvi",
ifelse.(q2[!,[:ast]].=="HOL","veiy",
ifelse.(q2[!,[:ast]].=="DBA","oexk",
"tfov"))))))))),select(q2,:sdc,:ast,:sc),
ifelse.(q2[!,[:sc]].==0,20,
ifelse.(q2[!,[:sc]].==1,40,
ifelse.(q2[!,[:sc]].==2,60,
ifelse.(q2[!,[:sc]].==3,80,
ifelse.(q2[!,[:sc]].==4,100,
ifelse.(q2[!,[:sc]].==5,0,
"ERROR")))))),
makeunique=true)
# Out:
# 910×5 DataFrame
#  Row │ ast     sdc     ast_1    sc     sc_1
#      │ String  Int64   String3  Int64  Int64
# ─────┼───────────────────────────────────────
#    1 │ fvxa    104618  KVH          3     80
#    2 │ fvxa    104891  KVH          5      0
#    3 │ fvxa    109220  KVH          5      0
#    4 │ fvxa    117939  KVH          5      0
#    5 │ fvxa    120912  KVH          5      0
#    6 │ fvxa    123875  KVH          3     80
#    7 │ fvxa    133826  KVH          2     60
#    8 │ fvxa    136541  KVH          4    100
#    9 │ fvxa    152692  KVH          4    100
#   10 │ fvxa    159842  KVH          5      0
#   11 │ fvxa    171109  KVH          2     60
#   ⋮  │   ⋮       ⋮        ⋮       ⋮      ⋮
#  901 │ tfov    586981  DOS          3     80
#  902 │ tfov    159842  DOS          5      0
#  903 │ tfov    854333  DOS          4    100
#  904 │ tfov    655715  DOS          4    100
#  905 │ tfov    123875  DOS          3     80
#  906 │ tfov    373901  DOS          5      0
#  907 │ tfov    480843  DOS          4    100
#  908 │ tfov    599697  DOS          5      0
#  909 │ tfov    868366  DOS          5      0
#  910 │ tfov    374400  DOS          3     80
#                              889 rows omitted

# %%
sort(combine(q2g,:sc => mean),:sc_mean,rev=true)
# Out:
# 13×2 DataFrame
#  Row │ ast      sc_mean
#      │ String3  Float64
# ─────┼──────────────────
#    1 │ EAG      3.32075
#    2 │ DBA      3.32075
#    3 │ EKS      3.17647
#    4 │ DOS      3.13462
#    5 │ JPS      2.88889
#    6 │ CTH      2.83636
#    7 │ MAD      2.79167
#    8 │ KVH      2.76812
#    9 │ MSN      2.68182
#   10 │ GSA      2.63235
#   11 │ POP      2.56604
#   12 │ HOL      2.50943
#   13 │ CTA      2.24138

# %%
using PlotlyJS
# Out:
# WebIO._IJuliaInit()

# %%
plot(combine(q2g,:sc => mean), x=:ast, y=:sc_mean, kind="bar")
# Out:
# data: [
#   "bar with fields type, x, xaxis, y, and yaxis"
# ]
#
# layout: "layout with fields legend, margin, template, xaxis, and yaxis"

# %%
q5=hcat(
ifelse.(q2[!,[:ast]].=="KVH","fvxa",
ifelse.(q2[!,[:ast]].=="EKS","yqoq",
ifelse.(q2[!,[:ast]].=="GSA","lqyc",
ifelse.(q2[!,[:ast]].=="MSN","jzck",
ifelse.(q2[!,[:ast]].=="JPS","cdlm",
ifelse.(q2[!,[:ast]].=="CTA","eion",
ifelse.(q2[!,[:ast]].=="EAG","qmvi",
ifelse.(q2[!,[:ast]].=="HOL","veiy",
ifelse.(q2[!,[:ast]].=="DBA","oexk",
"tfov"))))))))),select(q2,:sdc),
ifelse.(q2[!,[:sc]].==0,20,
ifelse.(q2[!,[:sc]].==1,40,
ifelse.(q2[!,[:sc]].==2,60,
ifelse.(q2[!,[:sc]].==3,80,
ifelse.(q2[!,[:sc]].==4,100,
ifelse.(q2[!,[:sc]].==5,0,
"ERROR")))))),
makeunique=true)
# Out:
# 910×3 DataFrame
#  Row │ ast     sdc     sc
#      │ String  Int64   Int64
# ─────┼───────────────────────
#    1 │ fvxa    104618     80
#    2 │ fvxa    104891      0
#    3 │ fvxa    109220      0
#    4 │ fvxa    117939      0
#    5 │ fvxa    120912      0
#    6 │ fvxa    123875     80
#    7 │ fvxa    133826     60
#    8 │ fvxa    136541    100
#    9 │ fvxa    152692    100
#   10 │ fvxa    159842      0
#   11 │ fvxa    171109     60
#   ⋮  │   ⋮       ⋮       ⋮
#  901 │ tfov    586981     80
#  902 │ tfov    159842      0
#  903 │ tfov    854333    100
#  904 │ tfov    655715    100
#  905 │ tfov    123875     80
#  906 │ tfov    373901      0
#  907 │ tfov    480843    100
#  908 │ tfov    599697      0
#  909 │ tfov    868366      0
#  910 │ tfov    374400     80
#              889 rows omitted

# %%
CSV.write("paperquizA.csv",q5)
# Out:
# "paperquizA.csv"

# %%
e1
# Out:
# 91×5 DataFrame
#  Row │ sc     sdc     sno       ln          fn
#      │ Int64  Int64   Int64     String15    String15
# ─────┼──────────────────────────────────────────────────
#    1 │    89  104618  53639084  Ma          Jenny
#    2 │     0  104891  21791843  Liu         Ryan
#    3 │    89  109220  47707195  Smith       Makyla
#    4 │     0  117939  62159470  Urban       Jessica ()
#    5 │     0  120912  46027488  Eng         Julie
#    6 │    91  123875  47130190  Morinaka    Kate
#    7 │    90  133826  32998205  Poon        Owen
#    8 │    93  136541  55693444  Stumborg    Esme
#    9 │    90  152692  81004772  Kaur        Kirin
#   10 │     0  159842  56710692  Duff        Allison
#   11 │    88  171109  59219527  Lister      Graeme
#   ⋮  │   ⋮      ⋮        ⋮          ⋮            ⋮
#   82 │    97  837888  85615573  Uppal       Jacquelyn
#   83 │    91  844462  52491586  Johal       Kajol
#   84 │    90  854333  38426516  Kohan       Anthony
#   85 │    90  855762  31888431  Brown       Maya
#   86 │     0  868366  76082957  Zhu         Kaida
#   87 │    89  904274  86002110  Sharma      Serena ()
#   88 │    91  911815  18496018  Schmitter   Cameron
#   89 │    90  935063  35311125  Roboobi     Khoobun
#   90 │    90  962740  75790980  Huang       Andrew
#   91 │    90  975179  27397421  Asawa       Vaidehi
#                                          70 rows omitted

# %%
e2=insertcols!(select(e1,:sdc,:sc),1,:ast .=> "zrys")
# Out:
# 91×3 DataFrame
#  Row │ ast     sdc     sc
#      │ String  Int64   Int64
# ─────┼───────────────────────
#    1 │ zrys    104618     89
#    2 │ zrys    104891      0
#    3 │ zrys    109220     89
#    4 │ zrys    117939      0
#    5 │ zrys    120912      0
#    6 │ zrys    123875     91
#    7 │ zrys    133826     90
#    8 │ zrys    136541     93
#    9 │ zrys    152692     90
#   10 │ zrys    159842      0
#   11 │ zrys    171109     88
#   ⋮  │   ⋮       ⋮       ⋮
#   82 │ zrys    837888     97
#   83 │ zrys    844462     91
#   84 │ zrys    854333     90
#   85 │ zrys    855762     90
#   86 │ zrys    868366      0
#   87 │ zrys    904274     89
#   88 │ zrys    911815     91
#   89 │ zrys    935063     90
#   90 │ zrys    962740     90
#   91 │ zrys    975179     90
#               70 rows omitted

# %%
CSV.write("essay1.csv",e2)
# Out:
# "essay1.csv"

# %%
e3=e2[e2.sc .> 0,:]
# Out:
# 71×3 DataFrame
#  Row │ ast     sdc     sc
#      │ String  Int64   Int64
# ─────┼───────────────────────
#    1 │ zrys    104618     89
#    2 │ zrys    109220     89
#    3 │ zrys    123875     91
#    4 │ zrys    133826     90
#    5 │ zrys    136541     93
#    6 │ zrys    152692     90
#    7 │ zrys    171109     88
#    8 │ zrys    171477     90
#    9 │ zrys    214934     90
#   10 │ zrys    217056     90
#   11 │ zrys    227667     90
#   ⋮  │   ⋮       ⋮       ⋮
#   62 │ zrys    829577     89
#   63 │ zrys    837888     97
#   64 │ zrys    844462     91
#   65 │ zrys    854333     90
#   66 │ zrys    855762     90
#   67 │ zrys    904274     89
#   68 │ zrys    911815     91
#   69 │ zrys    935063     90
#   70 │ zrys    962740     90
#   71 │ zrys    975179     90
#               50 rows omitted

# %%
freqtable(e3,:sc)
# Out:
# 9-element Named Vector{Int64}
# sc  │
# ────┼───
# 86  │  2
# 87  │  1
# 88  │  7
# 89  │ 11
# 90  │ 33
# 91  │ 11
# 92  │  4
# 93  │  1
# 97  │  1

# %%
mean(e3[:,:sc])
# Out:
# 89.90140845070422

# %%
combine(q4g,:sc_1 => mean)
# Out:
# 10×2 DataFrame
#  Row │ ast_1    sc_1_mean
#      │ String3  Float64
# ─────┼────────────────────
#    1 │ KVH        57.1429
#    2 │ EKS        62.4176
#    3 │ GSA        54.2857
#    4 │ MSN        53.4066
#    5 │ JPS        53.8462
#    6 │ CTA        41.3187
#    7 │ EAG        50.3297
#    8 │ HOL        40.8791
#    9 │ DBA        50.3297
#   10 │ DOS        47.2527
