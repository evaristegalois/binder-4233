# %%
using CSV
using DataFrames
using DataFramesMeta
using Statistics
using FreqTables

# %%
e1=DataFrame(CSV.File("./csv/e1.csv"))
# Out:
# 91×5 DataFrame
#  Row │ sc     sdc     sno       ln          fn
#      │ Int64  Int64   Int64     String15    String15
# ─────┼──────────────────────────────────────────────────
#    1 │    89  104618  53639084  Ma          Jenny
#    2 │     0  104891  21791843  Liu         Ryan
#    3 │    89  109220  47707195  Smith       Makyla
#    4 │     0  117939  62159470  Urban       Jessica ()
#    5 │     0  120912  46027488  Eng         Julie
#    6 │    91  123875  47130190  Morinaka    Kate
#    7 │    90  133826  32998205  Poon        Owen
#    8 │    93  136541  55693444  Stumborg    Esme
#    9 │    90  152692  81004772  Kaur        Kirin
#   10 │     0  159842  56710692  Duff        Allison
#   11 │    88  171109  59219527  Lister      Graeme
#   ⋮  │   ⋮      ⋮        ⋮          ⋮            ⋮
#   82 │    97  837888  85615573  Uppal       Jacquelyn
#   83 │    91  844462  52491586  Johal       Kajol
#   84 │    90  854333  38426516  Kohan       Anthony
#   85 │    90  855762  31888431  Brown       Maya
#   86 │     0  868366  76082957  Zhu         Kaida
#   87 │    89  904274  86002110  Sharma      Serena ()
#   88 │    91  911815  18496018  Schmitter   Cameron
#   89 │    90  935063  35311125  Roboobi     Khoobun
#   90 │    90  962740  75790980  Huang       Andrew
#   91 │    90  975179  27397421  Asawa       Vaidehi
#                                          70 rows omitted

# %%
a1=DataFrame(CSV.File("./csv/asts.csv"))
# Out:
# 24×2 DataFrame
#  Row │ asts     tla
#      │ String7  String3
# ─────┼──────────────────
#    1 │ fvxa     KVH
#    2 │ yqoq     EKS
#    3 │ fvxa     GSA
#    4 │ yqoq     MSN
#    5 │ cdlm     JPS
#    6 │ eion     CTA
#    7 │ qmvi     EAG
#    8 │ veiy     HOL
#    9 │ oexk     DBA
#   10 │ tfov     DOS
#   11 │ dduv     HGG
#   ⋮  │    ⋮        ⋮
#   15 │ lett     MFB
#   16 │ xfqk     CTC
#   17 │ prif     MFD
#   18 │ bosg     BUT
#   19 │ xega     VGL
#   20 │ obye     BAR
#   21 │ xxol     OMA
#   22 │ goag     OMB
#   23 │ kynz     KOL
#   24 │ aeyb     RSB
#           3 rows omitted

# %%
q1=DataFrame(CSV.File("./csv/quiz.csv"))
# Out:
# 910×6 DataFrame
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼──────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     5  KVH      104891  21791843  Liu         Ryan
#    3 │     5  KVH      109220  47707195  Smith       Makyla
#    4 │     5  KVH      117939  62159470  Urban       Jessica ()
#    5 │     5  KVH      120912  46027488  Eng         Julie
#    6 │     3  KVH      123875  47130190  Morinaka    Kate
#    7 │     2  KVH      133826  32998205  Poon        Owen
#    8 │     4  KVH      136541  55693444  Stumborg    Esme
#    9 │     4  KVH      152692  81004772  Kaur        Kirin
#   10 │     5  KVH      159842  56710692  Duff        Allison
#   11 │     2  KVH      171109  59219527  Lister      Graeme
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
#  901 │     3  DOS      586981  28761799  Dhillon     Simran
#  902 │     5  DOS      159842  56710692  Duff        Allison
#  903 │     4  DOS      854333  38426516  Kohan       Anthony
#  904 │     4  DOS      655715  50217298  Lee         Spencer
#  905 │     3  DOS      123875  47130190  Morinaka    Kate
#  906 │     5  DOS      373901  48709159  Peiro       Milad
#  907 │     4  DOS      480843  17009144  Wang        Sabrina
#  908 │     5  DOS      599697  86591872  Wilson      Isabel
#  909 │     5  DOS      868366  76082957  Zhu         Kaida
#  910 │     3  DOS      374400  79235719  Cuddington  Eero
#                                                 889 rows omitted

# %%
freqtable(q1[:,:sc])
# Out:
# 6-element Named Vector{Int64}
# Dim1  │
# ──────┼────
# 0     │  24
# 1     │  64
# 2     │ 115
# 3     │ 171
# 4     │ 229
# 5     │ 307

# %%
q1g=groupby(q1,:ast)
# Out:
# GroupedDataFrame with 10 groups based on key: ast
# First Group (91 rows): ast = "KVH"
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼───────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     5  KVH      104891  21791843  Liu         Ryan
#    3 │     5  KVH      109220  47707195  Smith       Makyla
#    4 │     5  KVH      117939  62159470  Urban       Jessica ()
#    5 │     5  KVH      120912  46027488  Eng         Julie
#    6 │     3  KVH      123875  47130190  Morinaka    Kate
#    7 │     2  KVH      133826  32998205  Poon        Owen
#    8 │     4  KVH      136541  55693444  Stumborg    Esme
#    9 │     4  KVH      152692  81004772  Kaur        Kirin
#   10 │     5  KVH      159842  56710692  Duff        Allison
#   11 │     2  KVH      171109  59219527  Lister      Graeme
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮            ⋮
#   81 │     3  KVH      829577  27307339  Chen        Emily
#   82 │     2  KVH      837888  85615573  Uppal       Jacquelyn
#   83 │     2  KVH      844462  52491586  Johal       Kajol
#   84 │     4  KVH      854333  38426516  Kohan       Anthony
#   85 │     3  KVH      855762  31888431  Brown       Maya
#   86 │     5  KVH      868366  76082957  Zhu         Kaida
#   87 │     4  KVH      904274  86002110  Sharma      Serena ()
#   88 │     3  KVH      911815  18496018  Schmitter   Cameron
#   89 │     5  KVH      935063  35311125  Roboobi     Khoobun
#   90 │     4  KVH      962740  75790980  Huang       Andrew
#   91 │     4  KVH      975179  27397421  Asawa       Vaidehi
#                                                   69 rows omitted
# ⋮
# Last Group (91 rows): ast = "DOS"
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼────────────────────────────────────────────────────────────
#    1 │     5  DOS      758592  73627077  Anand       Shaurya Veer
#    2 │     4  DOS      596235  22340012  Arasu       Menaka
#    3 │     1  DOS      975179  27397421  Asawa       Vaidehi
#    4 │     5  DOS      739244  83795476  Barbashov   Yury
#    5 │     4  DOS      408620  33241019  Beesley     Tabby
#    6 │     4  DOS      524203  97714976  Bienert     Bella
#    7 │     2  DOS      767173  19909522  Bobyn       Alex ()
#    8 │     4  DOS      329294  42623306  Boivin      Jack Thomas
#    9 │     5  DOS      855762  31888431  Brown       Maya
#   10 │     4  DOS      782903  82091455  Cader       Sarah
#   11 │     3  DOS      685939  77049898  Chambers    Colby
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮            ⋮
#   81 │     5  DOS      529445  23912637  Chang       Ian
#   82 │     3  DOS      586981  28761799  Dhillon     Simran
#   83 │     5  DOS      159842  56710692  Duff        Allison
#   84 │     4  DOS      854333  38426516  Kohan       Anthony
#   85 │     4  DOS      655715  50217298  Lee         Spencer
#   86 │     3  DOS      123875  47130190  Morinaka    Kate
#   87 │     5  DOS      373901  48709159  Peiro       Milad
#   88 │     4  DOS      480843  17009144  Wang        Sabrina
#   89 │     5  DOS      599697  86591872  Wilson      Isabel
#   90 │     5  DOS      868366  76082957  Zhu         Kaida
#   91 │     3  DOS      374400  79235719  Cuddington  Eero
#                                                    69 rows omitted

# %%
show(combine(q1g,:sc => freqtable),allrows=true)
# Out:
# 57×2 DataFrame
#  Row │ ast      sc_freqtable
#      │ String3  Int64
# ─────┼───────────────────────
#    1 │ KVH                 1
#    2 │ KVH                11
#    3 │ KVH                16
#    4 │ KVH                16
#    5 │ KVH                25
#    6 │ KVH                22
#    7 │ EKS                 5
#    8 │ EKS                 6
#    9 │ EKS                29
#   10 │ EKS                28
#   11 │ EKS                23
#   12 │ GSA                 3
#   13 │ GSA                 8
#   14 │ GSA                14
#   15 │ GSA                29
#   16 │ GSA                14
#   17 │ GSA                23
#   18 │ MSN                 2
#   19 │ MSN                 9
#   20 │ MSN                17
#   21 │ MSN                18
#   22 │ MSN                20
#   23 │ MSN                25
#   24 │ JPS                 2
#   25 │ JPS                 4
#   26 │ JPS                18
#   27 │ JPS                14
#   28 │ JPS                25
#   29 │ JPS                28
#   30 │ CTA                12
#   31 │ CTA                 9
#   32 │ CTA                 7
#   33 │ CTA                13
#   34 │ CTA                17
#   35 │ CTA                33
#   36 │ EAG                 3
#   37 │ EAG                10
#   38 │ EAG                 7
#   39 │ EAG                33
#   40 │ EAG                38
#   41 │ HOL                 3
#   42 │ HOL                 7
#   43 │ HOL                16
#   44 │ HOL                14
#   45 │ HOL                13
#   46 │ HOL                38
#   47 │ DBA                 1
#   48 │ DBA                 2
#   49 │ DBA                 4
#   50 │ DBA                18
#   51 │ DBA                28
#   52 │ DBA                38
#   53 │ DOS                 6
#   54 │ DOS                 7
#   55 │ DOS                13
#   56 │ DOS                26
#   57 │ DOS                39

# %%
q2=q1
# Out:
# 910×6 DataFrame
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼──────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     5  KVH      104891  21791843  Liu         Ryan
#    3 │     5  KVH      109220  47707195  Smith       Makyla
#    4 │     5  KVH      117939  62159470  Urban       Jessica ()
#    5 │     5  KVH      120912  46027488  Eng         Julie
#    6 │     3  KVH      123875  47130190  Morinaka    Kate
#    7 │     2  KVH      133826  32998205  Poon        Owen
#    8 │     4  KVH      136541  55693444  Stumborg    Esme
#    9 │     4  KVH      152692  81004772  Kaur        Kirin
#   10 │     5  KVH      159842  56710692  Duff        Allison
#   11 │     2  KVH      171109  59219527  Lister      Graeme
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
#  901 │     3  DOS      586981  28761799  Dhillon     Simran
#  902 │     5  DOS      159842  56710692  Duff        Allison
#  903 │     4  DOS      854333  38426516  Kohan       Anthony
#  904 │     4  DOS      655715  50217298  Lee         Spencer
#  905 │     3  DOS      123875  47130190  Morinaka    Kate
#  906 │     5  DOS      373901  48709159  Peiro       Milad
#  907 │     4  DOS      480843  17009144  Wang        Sabrina
#  908 │     5  DOS      599697  86591872  Wilson      Isabel
#  909 │     5  DOS      868366  76082957  Zhu         Kaida
#  910 │     3  DOS      374400  79235719  Cuddington  Eero
#                                                 889 rows omitted

# %%
q3=hcat(
ifelse.(q2[!,[:ast]].=="KVH","fvxa",
ifelse.(q2[!,[:ast]].=="EKS","yqoq",
ifelse.(q2[!,[:ast]].=="GSA","fvxa",
ifelse.(q2[!,[:ast]].=="MSN","yqoq",
ifelse.(q2[!,[:ast]].=="JPS","cdlm",
ifelse.(q2[!,[:ast]].=="CTA","eion",
ifelse.(q2[!,[:ast]].=="EAG","qmvi",
ifelse.(q2[!,[:ast]].=="HOL","veiy",
ifelse.(q2[!,[:ast]].=="DBA","oexk",
"tfov"))))))))),rename(q2,:ast=>:astid))
# Out:
# 910×7 DataFrame
#  Row │ ast     sc     astid    sdc     sno       ln          fn
#      │ String  Int64  String3  Int64   Int64     String15    String15
# ─────┼──────────────────────────────────────────────────────────────────
#    1 │ fvxa        3  KVH      104618  53639084  Ma          Jenny
#    2 │ fvxa        5  KVH      104891  21791843  Liu         Ryan
#    3 │ fvxa        5  KVH      109220  47707195  Smith       Makyla
#    4 │ fvxa        5  KVH      117939  62159470  Urban       Jessica ()
#    5 │ fvxa        5  KVH      120912  46027488  Eng         Julie
#    6 │ fvxa        3  KVH      123875  47130190  Morinaka    Kate
#    7 │ fvxa        2  KVH      133826  32998205  Poon        Owen
#    8 │ fvxa        4  KVH      136541  55693444  Stumborg    Esme
#    9 │ fvxa        4  KVH      152692  81004772  Kaur        Kirin
#   10 │ fvxa        5  KVH      159842  56710692  Duff        Allison
#   11 │ fvxa        2  KVH      171109  59219527  Lister      Graeme
#   ⋮  │   ⋮       ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
#  901 │ tfov        3  DOS      586981  28761799  Dhillon     Simran
#  902 │ tfov        5  DOS      159842  56710692  Duff        Allison
#  903 │ tfov        4  DOS      854333  38426516  Kohan       Anthony
#  904 │ tfov        4  DOS      655715  50217298  Lee         Spencer
#  905 │ tfov        3  DOS      123875  47130190  Morinaka    Kate
#  906 │ tfov        5  DOS      373901  48709159  Peiro       Milad
#  907 │ tfov        4  DOS      480843  17009144  Wang        Sabrina
#  908 │ tfov        5  DOS      599697  86591872  Wilson      Isabel
#  909 │ tfov        5  DOS      868366  76082957  Zhu         Kaida
#  910 │ tfov        3  DOS      374400  79235719  Cuddington  Eero
#                                                         889 rows omitted

# %%
q4=hcat(
ifelse.(q2[!,[:ast]].=="KVH","fvxa",
ifelse.(q2[!,[:ast]].=="EKS","yqoq",
ifelse.(q2[!,[:ast]].=="GSA","fvxa",
ifelse.(q2[!,[:ast]].=="MSN","yqoq",
ifelse.(q2[!,[:ast]].=="JPS","cdlm",
ifelse.(q2[!,[:ast]].=="CTA","eion",
ifelse.(q2[!,[:ast]].=="EAG","qmvi",
ifelse.(q2[!,[:ast]].=="HOL","veiy",
ifelse.(q2[!,[:ast]].=="DBA","oexk",
"tfov"))))))))),select(q2,:sdc,:ast,:sc),
ifelse.(q2[!,[:sc]].==0,20,
ifelse.(q2[!,[:sc]].==1,40,
ifelse.(q2[!,[:sc]].==2,60,
ifelse.(q2[!,[:sc]].==3,80,
ifelse.(q2[!,[:sc]].==4,100,
ifelse.(q2[!,[:sc]].==5,0,
"ERROR")))))),
makeunique=true)
# Out:
# 910×5 DataFrame
#  Row │ ast     sdc     ast_1    sc     sc_1
#      │ String  Int64   String3  Int64  Int64
# ─────┼───────────────────────────────────────
#    1 │ fvxa    104618  KVH          3     80
#    2 │ fvxa    104891  KVH          5      0
#    3 │ fvxa    109220  KVH          5      0
#    4 │ fvxa    117939  KVH          5      0
#    5 │ fvxa    120912  KVH          5      0
#    6 │ fvxa    123875  KVH          3     80
#    7 │ fvxa    133826  KVH          2     60
#    8 │ fvxa    136541  KVH          4    100
#    9 │ fvxa    152692  KVH          4    100
#   10 │ fvxa    159842  KVH          5      0
#   11 │ fvxa    171109  KVH          2     60
#   ⋮  │   ⋮       ⋮        ⋮       ⋮      ⋮
#  901 │ tfov    586981  DOS          3     80
#  902 │ tfov    159842  DOS          5      0
#  903 │ tfov    854333  DOS          4    100
#  904 │ tfov    655715  DOS          4    100
#  905 │ tfov    123875  DOS          3     80
#  906 │ tfov    373901  DOS          5      0
#  907 │ tfov    480843  DOS          4    100
#  908 │ tfov    599697  DOS          5      0
#  909 │ tfov    868366  DOS          5      0
#  910 │ tfov    374400  DOS          3     80
#                              889 rows omitted

# %%
q4g=groupby(q4,:ast_1)
# Out:
# GroupedDataFrame with 10 groups based on key: ast_1
# First Group (91 rows): ast_1 = "KVH"
#  Row │ ast     sdc     ast_1    sc     sc_1
#      │ String  Int64   String3  Int64  Int64
# ─────┼───────────────────────────────────────
#    1 │ fvxa    104618  KVH          3     80
#    2 │ fvxa    104891  KVH          5      0
#    3 │ fvxa    109220  KVH          5      0
#    4 │ fvxa    117939  KVH          5      0
#    5 │ fvxa    120912  KVH          5      0
#    6 │ fvxa    123875  KVH          3     80
#    7 │ fvxa    133826  KVH          2     60
#    8 │ fvxa    136541  KVH          4    100
#    9 │ fvxa    152692  KVH          4    100
#   10 │ fvxa    159842  KVH          5      0
#   11 │ fvxa    171109  KVH          2     60
#   ⋮  │   ⋮       ⋮        ⋮       ⋮      ⋮
#   81 │ fvxa    829577  KVH          3     80
#   82 │ fvxa    837888  KVH          2     60
#   83 │ fvxa    844462  KVH          2     60
#   84 │ fvxa    854333  KVH          4    100
#   85 │ fvxa    855762  KVH          3     80
#   86 │ fvxa    868366  KVH          5      0
#   87 │ fvxa    904274  KVH          4    100
#   88 │ fvxa    911815  KVH          3     80
#   89 │ fvxa    935063  KVH          5      0
#   90 │ fvxa    962740  KVH          4    100
#   91 │ fvxa    975179  KVH          4    100
#                               69 rows omitted
# ⋮
# Last Group (91 rows): ast_1 = "DOS"
#  Row │ ast     sdc     ast_1    sc     sc_1
#      │ String  Int64   String3  Int64  Int64
# ─────┼───────────────────────────────────────
#    1 │ tfov    758592  DOS          5      0
#    2 │ tfov    596235  DOS          4    100
#    3 │ tfov    975179  DOS          1     40
#    4 │ tfov    739244  DOS          5      0
#    5 │ tfov    408620  DOS          4    100
#    6 │ tfov    524203  DOS          4    100
#    7 │ tfov    767173  DOS          2     60
#    8 │ tfov    329294  DOS          4    100
#    9 │ tfov    855762  DOS          5      0
#   10 │ tfov    782903  DOS          4    100
#   11 │ tfov    685939  DOS          3     80
#   ⋮  │   ⋮       ⋮        ⋮       ⋮      ⋮
#   81 │ tfov    529445  DOS          5      0
#   82 │ tfov    586981  DOS          3     80
#   83 │ tfov    159842  DOS          5      0
#   84 │ tfov    854333  DOS          4    100
#   85 │ tfov    655715  DOS          4    100
#   86 │ tfov    123875  DOS          3     80
#   87 │ tfov    373901  DOS          5      0
#   88 │ tfov    480843  DOS          4    100
#   89 │ tfov    599697  DOS          5      0
#   90 │ tfov    868366  DOS          5      0
#   91 │ tfov    374400  DOS          3     80
#                               69 rows omitted

# %%
sort(combine(q4g,:sc_1 => mean),:sc_1_mean,rev=true)
# Out:
# 10×2 DataFrame
#  Row │ ast_1    sc_1_mean
#      │ String3  Float64
# ─────┼────────────────────
#    1 │ EKS        62.4176
#    2 │ KVH        57.1429
#    3 │ GSA        54.2857
#    4 │ JPS        53.8462
#    5 │ MSN        53.4066
#    6 │ EAG        50.3297
#    7 │ DBA        50.3297
#    8 │ DOS        47.2527
#    9 │ CTA        41.3187
#   10 │ HOL        40.8791

# %%
q5=hcat(
ifelse.(q2[!,[:ast]].=="KVH","fvxa",
ifelse.(q2[!,[:ast]].=="EKS","yqoq",
ifelse.(q2[!,[:ast]].=="GSA","fvxa",
ifelse.(q2[!,[:ast]].=="MSN","yqoq",
ifelse.(q2[!,[:ast]].=="JPS","cdlm",
ifelse.(q2[!,[:ast]].=="CTA","eion",
ifelse.(q2[!,[:ast]].=="EAG","qmvi",
ifelse.(q2[!,[:ast]].=="HOL","veiy",
ifelse.(q2[!,[:ast]].=="DBA","oexk",
"tfov"))))))))),select(q2,:sdc),
ifelse.(q2[!,[:sc]].==0,20,
ifelse.(q2[!,[:sc]].==1,40,
ifelse.(q2[!,[:sc]].==2,60,
ifelse.(q2[!,[:sc]].==3,80,
ifelse.(q2[!,[:sc]].==4,100,
ifelse.(q2[!,[:sc]].==5,0,
"ERROR")))))),
makeunique=true)
