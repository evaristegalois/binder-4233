# %%
x=[25
5
25]
# Out:
# 3-element Vector{Int64}:
#  25
#   5
#  25

# %%
xd=x/length(x)
# Out:
# 3-element Vector{Float64}:
#  8.333333333333334
#  1.6666666666666667
#  8.333333333333334

# %%
70*xd
# Out:
# 3-element Vector{Float64}:
#  583.3333333333334
#  116.66666666666667
#  583.3333333333334

# %%
x*(75/55)
# Out:
# 3-element Vector{Float64}:
#  34.090909090909086
#   6.8181818181818175
#  34.090909090909086

# %%
g=32
# Out:
# 32

# %%
t1=46/g
# Out:
# 1.4375

# %%
-0.5*g*t1^2+46*t1
# Out:
# 33.0625

# %%
y(t)=(-g*sqrt(2)/92)*t^2+t
# Out:
# y (generic function with 1 method)

# %%
t1=92/(g*sqrt(2))
# Out:
# 2.032931995911324

# %%
t2=(23*sqrt(2)/g)
# Out:
# 1.016465997955662

# %%
y(t2)
# Out:
# 0.508232998977831

# %%
23^2*2
# Out:
# 1058

# %%
(-1//12)+(-32//100)
# Out:
# -121//300

# %%
8*13
# Out:
# 104

# %%
using Polynomials

# %%
p1=Polynomial([80,8,2])
# Out:
# Polynomial(80 + 8*x + 2*x^2)

# %%
roots(p1)
# Out:
# 2-element Vector{ComplexF64}:
#  -1.9999999999999996 - 6.0im
#  -1.9999999999999996 + 6.0im

# %%
7*12
# Out:
# 84

# %%
20*32
# Out:
# 640

# %%
p2=Polynomial([20,4,4/32])
# Out:
# Polynomial(20.0 + 4.0*x + 0.125*x^2)

# %%
sol=roots(p2)
# Out:
# 2-element Vector{Float64}:
#  -25.79795897113271
#   -6.202041028867288

# %%
om=imag(sol[2,1])
# Out:
# 69.74238309665077

# %%
A=2/om
# Out:
# 0.028676966733820225

# %%
using LinearAlgebra

# %%
M3=[1 1
sol[1,1] sol[2,1]]
# Out:
# 2×2 Matrix{Float64}:
#    1.0     1.0
#  -25.798  -6.20204

# %%
v3=[0
2]
# Out:
# 2-element Vector{Int64}:
#  0
#  2

# %%
inv(M3)*v3
# Out:
# 2-element Vector{Float64}:
#  -0.10206207261596575
#   0.10206207261596575

# %%
p4=Polynomial([13,6,1])
# Out:
# Polynomial(13 + 6*x + x^2)

# %%
roots(p4)
# Out:
# 2-element Vector{ComplexF64}:
#  -3.0000000000000004 - 2.0im
#  -3.0000000000000004 + 2.0im

# %%
using Polynomials

# %%
p1=Polynomial([233,-16,1])
# Out:
# Polynomial(233 - 16*x + x^2)

# %%
roots(p1)
# Out:
# 2-element Vector{ComplexF64}:
#  7.999999999999999 - 13.0im
#  7.999999999999999 + 13.0im

# %%
x1=7991.27
# Out:
# 7991.27

# %%
x2=x1-2*3975
# Out:
# 41.27000000000044

# %%
1987.50-100-41.27
# Out:
# 1846.23

# %%
f(x)=2^x-x^2
# Out:
# f (generic function with 1 method)

# %%
fp(x)=log(2)*2^x-2*x
# Out:
# fp (generic function with 1 method)

# %%
x0=-1.0
# Out:
# -1.0

# %%
x1=x0-(f(x0)/fp(x0))
# Out:
# -0.7869233668736788

# %%
x2=x1-(f(x1)/fp(x1))
# Out:
# -0.7668433793547702

# %%
x3=x2-(f(x2)/fp(x2))
# Out:
# -0.7666647100884709

# %%
using Roots

# %%
z=find_zero(f,-1)
# Out:
# -0.766664695962123

# %%
F(x)=(1/log(2))*2^x-(x^3/3)
# Out:
# F (generic function with 1 method)

# %%
F(2)-F(z)
# Out:
# 2.1059250529883626

# %%
29/25+42/50
# Out:
# 2.0

# %%
f(x)=exp(x^2)-5*cos(x)
# Out:
# f (generic function with 1 method)

# %%
find_zero(f,-1)
# Out:
# -0.9982580630335174

# %%
f(x)=x+1.4*sqrt(194-26*x+x^2)
# Out:
# f (generic function with 1 method)

# %%
using Calculus

# %%
differentiate("x+1.4*sqrt(194-26*x+x^2)",:x)
# Out:
# :(1 + (0 * sqrt((194 - 26x) + x ^ 2) + 1.4 * (((0 - (0 * x + 26 * 1)) + 2 * 1 * x ^ (2 - 1)) * ((1 / 2) / sqrt((194 - 26x) + x ^ 2)))))

# %%
fp(x)=(1 + (0 * sqrt((194 - 26x) + x ^ 2) + 1.4 * (((0 - (0 * x + 26 * 1)) + 2 * 1 * x ^ (2 - 1)) * ((1 / 2) / sqrt((194 - 26x) + x ^ 2)))))
# Out:
# fp (generic function with 1 method)

# %%
find_zero(fp,7)
# Out:
# 7.896896369201711

# %%
using Polynomials

# %%
p1=Polynomial([169*49-25*194,25*26-26*49,24])
# Out:
# Polynomial(3431 - 624*x + 24*x^2)

# %%
roots(p1)
# Out:
# 2-element Vector{Float64}:
#   7.89689636920171
#  18.10310363079829

# %%
(1/15)*64*pi*sqrt(2)
# Out:
# 18.95630053614236

# %%
F(y)=(1/5)*y^5-(4/3)*y^3+4*y
# Out:
# F (generic function with 1 method)

# %%
(F(sqrt(2))-F(-sqrt(2)))*pi
# Out:
# 18.95630053614236

# %%
using SymPy

# %%
@vars t
# Out:
# (t,)

# %%
A1=[5 5
-5 -3]
# Out:
# 2×2 Matrix{Int64}:
#   5   5
#  -5  -3

# %%
exp(*(A1,t))
# Out:
# 2×2 Matrix{Sym}:
#  -5*I*(-4/5 + 3*I/5)*exp(t*(1 - 3*I))/6 + 5*I*(-4/5 - 3*I/5)*exp(t*(1 + 3*I))/6  …  (-4/5 + 3*I/5)*(1/2 - 2*I/3)*exp(t*(1 - 3*I)) + (-4/5 - 3*I/5)*(1/2 + 2*I/3)*exp(t*(1 + 3*I))
#                                -5*I*exp(t*(1 - 3*I))/6 + 5*I*exp(t*(1 + 3*I))/6                                   (1/2 - 2*I/3)*exp(t*(1 - 3*I)) + (1/2 + 2*I/3)*exp(t*(1 + 3*I))

# %%
(-2//9)-(16//45)
# Out:
# -26//45

# %%
*(42499.93,0.049,/(1,12))
# Out:
# 173.54138083333333

# %%
+(*(400,0.037,/(5,12)),*(100,0.037,/(6,12)))
# Out:
# 8.016666666666666

# %%
*(100,0.037,/(1,12))
# Out:
# 0.3083333333333333

# %%
*(82.84,/(56,59))
# Out:
# 78.6277966101695

# %%
using Plots

# %%
xs=range(-2,stop=2,length=100)
# Out:
# -2.0:0.04040404040404041:2.0

# %%
ys=range(-2,stop=2,length=100)
# Out:
# -2.0:0.04040404040404041:2.0

# %%
f(x,y)=*(/(1,180),+(7400,*(-4,x),*(-9,y),*(0.03,x,y)))
# Out:
# f (generic function with 1 method)

# %%
f(x,y)=+(4,*(-1,^(x,2)),*(-1,^(y,2)))
# Out:
# f (generic function with 1 method)

# %%
surface(xs,ys,f)

# %%
/(/(1,9),-(1,/(2,81)))
# Out:
# 0.11392405063291139

# %%
*(^(/(6,7),5),/(1,-(1,/(6,7))))
# Out:
# 3.2386505622657205

# %%
+(*(/(6,7),/(1,-(1,/(6,7)))),*(/(2,7),/(1,-(1,/(2,7)))))
# Out:
# 6.399999999999998

# %%
op=[3;1;-2]
# Out:
# 3-element Vector{Int64}:
#   3
#   1
#  -2

# %%
oq=[-5;-1;3]
# Out:
# 3-element Vector{Int64}:
#  -5
#  -1
#   3

# %%
orr=[2;0;4]
# Out:
# 3-element Vector{Int64}:
#  2
#  0
#  4

# %%
pq=oq-op
# Out:
# 3-element Vector{Int64}:
#  -8
#  -2
#   5

# %%
pr=orr-op
# Out:
# 3-element Vector{Int64}:
#  -1
#  -1
#   6

# %%
using LinearAlgebra

# %%
cross(pq,pr)
# Out:
# 3-element Vector{Int64}:
#  -7
#  43
#   6

# %%
(1//9)//(1-(2//81))
# Out:
# 9//79

# %%
((6//7)^5)//(1-(6//7))
# Out:
# 7776//2401

# %%
using Polynomials

# %%
p1=Polynomial([-306,-27,34,3])
# Out:
# Polynomial(-306 - 27*x + 34*x^2 + 3*x^3)

# %%
roots(p1)
# Out:
# 3-element Vector{Float64}:
#  -11.333333333333329
#   -3.0000000000000013
#    3.000000000000001

# %%
using SymPy
# Out:
# WARNING: using SymPy.roots in module Main conflicts with an existing identifier.

# %%
@vars s
# Out:
# (s,)

# %%
apart(/(+(*(3,s),34),*(+(s,9),+(s,3),-(s,3),+(*(3,s),11))))
# Out:
#      621              7             25            43
# ────────────── - ──────────── - ────────── + ────────────
# 640⋅(3⋅s + 11)   1152⋅(s + 9)   72⋅(s + 3)   1440⋅(s - 3)

# %%
apart(/(1,*(+(s,9),+(s,3),-(s,3))))
# Out:
#     1            1            1
# ────────── - ────────── + ──────────
# 72⋅(s + 9)   36⋅(s + 3)   72⋅(s - 3)

# %%
p2=Polynomial([98,-56,8])
# Out:
# Polynomial(98 - 56*x + 8*x^2)

# %%
roots(p2)
# Out:
# 2-element Vector{Float64}:
#  3.5
#  3.5

# %%
using Polynomials

# %%
p1=Polynomial([53,14,1])
# Out:
# Polynomial(53 + 14*x + x^2)

# %%
roots(p1)
# Out:
# 2-element Vector{ComplexF64}:
#  -6.999999999999999 - 1.9999999999999984im
#  -6.999999999999999 + 1.9999999999999984im

# %%
sinh(1)
# Out:
# 1.1752011936438014

# %%
dxdt=-(*(80,exp(1),/(1,sqrt(2)),sin(*(80,-(1,exp(1)))),10),*(/(1,sqrt(2)),/(pi,8),+(13,*(10,cos(*(80,-(1,exp(1))))))))
# Out:
# 1062.1043412848962

# %%
dydt=*(10,cos(*(80,-(1,exp(1)))),*(-80,exp(1)))
# Out:
# -1564.9204979021683

# %%
dzdt=+(*(10,80,exp(1),/(1,sqrt(2)),sin(*(80,-(1,exp(1))))),*(+(13,*(10,cos(*(80,-(1,exp(1)))))),/(1,sqrt(2)),/(pi,8)))
# Out:
# 1073.320552529562

# %%
using LinearAlgebra

# %%
v1=[dxdt;dydt;dzdt]
# Out:
# 3-element Vector{Float64}:
#   1062.1043412848962
#  -1564.9204979021683
#   1073.320552529562

# %%
s1=sqrt(dot(v1,v1))
# Out:
# 2174.6399253699356

# %%
/(*(s1,60),1000)
# Out:
# 130.47839552219614

# %%
x1=14.281
# Out:
# 14.281

# %%
y1=6.944
# Out:
# 6.944

# %%
R=10
# Out:
# 10

# %%
A=13
# Out:
# 13

# %%
tht(t)=*(80,-(1,exp(t)))
# Out:
# tht (generic function with 1 method)

# %%
psi(t)=/(*(pi,t),*(2,+(t,1)))
# Out:
# psi (generic function with 1 method)

# %%
secxt(t)=+(*(-R,cos(psi(t)),cos(tht(t)),*(6400,exp(*(2,t)))),*(2,R,sin(psi(t)),sin(tht(t)),*(-80,exp(t)),/(pi,*(2,^(+(t,1),2)))),*(-(*(-A,cos(psi(t)))),*(R,cos(tht(t)),cos(psi(t))),/(^(pi,2),*(4,^(+(t,1),4)))),*(R,cos(psi(t)),sin(tht(t)),/(pi,^(+(t,1),3))),*(+(*(A,sin(psi(t))),*(R,cos(tht(t)),sin(psi(t)))),/(pi,^(+(t,1),3))))
# Out:
# secxt (generic function with 1 method)

# %%
secxt(1)
# Out:
# -241460.46715865284

# %%
using SymPy

# %%
@vars x
# Out:
# (x,)

# %%
SymPy.integrate(SymPy.sin(*(2,x)))
# Out:
# -cos(2⋅x)
# ──────────
#     2

# %%
SymPy.integrate(^(SymPy.cos(*(2,x)),2))
# Out:
# x   sin(2⋅x)⋅cos(2⋅x)
# ─ + ─────────────────
# 2           4

# %%
+(9,10,12,10,11,14,11,12,8)
# Out:
# 97
