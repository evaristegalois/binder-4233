# %%
using CSV, DataFrames, Statistics, FreqTables

# %%
q1=DataFrame(CSV.File("./csv/quiz.csv"))
# Out:
# 1729×6 DataFrame
#   Row │ sc     ast      sdc     sno       ln          fn
#       │ Int64  String3  Int64   Int64     String15    String15
# ──────┼──────────────────────────────────────────────────────────
#     1 │     3  KVH      104618  53639084  Ma          Jenny
#     2 │     5  KVH      104891  21791843  Liu         Ryan
#     3 │     5  KVH      109220  47707195  Smith       Makyla
#     4 │     5  KVH      117939  62159470  Urban       Jessica ()
#     5 │     5  KVH      120912  46027488  Eng         Julie
#     6 │     3  KVH      123875  47130190  Morinaka    Kate
#     7 │     2  KVH      133826  32998205  Poon        Owen
#     8 │     4  KVH      136541  55693444  Stumborg    Esme
#     9 │     4  KVH      152692  81004772  Kaur        Kirin
#    10 │     5  KVH      159842  56710692  Duff        Allison
#    11 │     2  KVH      171109  59219527  Lister      Graeme
#   ⋮   │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
# ...

# %%
freqtable(q1[:,:sc])
# Out:
# 6-element Named Vector{Int64}
# Dim1  │
# ──────┼────
# 0     │  52
# 1     │ 129
# 2     │ 236
# 3     │ 296
# 4     │ 372
# 5     │ 644

# %%
q2=q1[q1.sc .< 5,:] # filter out absences
# Out:
# 1085×6 DataFrame
#   Row │ sc     ast      sdc     sno       ln          fn
#       │ Int64  String3  Int64   Int64     String15    String15
# ──────┼─────────────────────────────────────────────────────────
#     1 │     3  KVH      104618  53639084  Ma          Jenny
#     2 │     3  KVH      123875  47130190  Morinaka    Kate
#     3 │     2  KVH      133826  32998205  Poon        Owen
#     4 │     4  KVH      136541  55693444  Stumborg    Esme
#     5 │     4  KVH      152692  81004772  Kaur        Kirin
#     6 │     2  KVH      171109  59219527  Lister      Graeme
#     7 │     4  KVH      171477  78865573  Stampliaka  Caroline
#     8 │     4  KVH      214934  34099135  Zhao        Curtis
#     9 │     3  KVH      217056  48465041  Lee         Daniel
#    10 │     2  KVH      230494  22250328  Zeng        Sabrina
#    11 │     4  KVH      251974  22885628  Imura       Dennis
#   ⋮   │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
# ...

# %%
/(mean(q2[:,:sc]),4) # mean score
# Out:
# 0.6859447004608294

# %%
q2g=groupby(q2,:ast)
# Out:
# GroupedDataFrame with 19 groups based on key: ast
# First Group (69 rows): ast = "KVH"
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼─────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     3  KVH      123875  47130190  Morinaka    Kate
#    3 │     2  KVH      133826  32998205  Poon        Owen
#    4 │     4  KVH      136541  55693444  Stumborg    Esme
#    5 │     4  KVH      152692  81004772  Kaur        Kirin
#    6 │     2  KVH      171109  59219527  Lister      Graeme
#    7 │     4  KVH      171477  78865573  Stampliaka  Caroline
#    8 │     4  KVH      214934  34099135  Zhao        Curtis
#    9 │     3  KVH      217056  48465041  Lee         Daniel
#   10 │     2  KVH      230494  22250328  Zeng        Sabrina
#   11 │     4  KVH      251974  22885628  Imura       Dennis
# ...

# %%
sort(combine(q2g,:sc => mean),:sc_mean,rev=true)
# Out:
# 19×2 DataFrame
#  Row │ ast      sc_mean
#      │ String3  Float64
# ─────┼──────────────────
#    1 │ EAG      3.2963
#    2 │ DBA      3.2963
#    3 │ BUT      3.21569
#    4 │ EKS      3.17647
#    5 │ DOS      3.13208
#    6 │ JPS      2.88889
#    7 │ CTH      2.83636
#    8 │ MAD      2.79167
#    9 │ KVH      2.76812
#   10 │ OMA      2.7451
#   11 │ OMB      2.71154
#   12 │ MSN      2.68182
#   13 │ GSA      2.63235
#   14 │ POP      2.56604
#   15 │ HOL      2.5
#   16 │ BAR      2.30909
#   17 │ CTA      2.24138
#   18 │ VGL      2.2
#   19 │ MFB      2.17241

# %%
d1=Dict( "KVH" => "fvxa", "EKS" => "yqoq", "GSA" => "lqyc", "MSN" => "jzck", "JPS" => "cdlm", "CTA" => "eion", "EAG" => "qmvi", "HOL" => "veiy", "DBA" => "oexk", "DOS" => "tfov", "CTH" => "hrti", "POP" => "ifai", "MAD" => "lett", "MFB" => "xfqk", "BAR" => "prif", "BUT" => "bosg", "VGL" => "xega", "OMA" => "xxol", "OMB" => "goag")
# Out:
# Dict{String, String} with 19 entries:
#   "MFB" => "xfqk"
#   "JPS" => "cdlm"
#   "BAR" => "prif"
#   "CTA" => "eion"
#   "BUT" => "bosg"
#   "GSA" => "lqyc"
#   "DOS" => "tfov"
#   "MAD" => "lett"
#   "OMB" => "goag"
#   "EKS" => "yqoq"
#   "CTH" => "hrti"
#   "MSN" => "jzck"
#   "VGL" => "xega"
#   "OMA" => "xxol"
#   "POP" => "ifai"
#   "KVH" => "fvxa"
#   "HOL" => "veiy"
#   "DBA" => "oexk"
#   "EAG" => "qmvi"

# %%
d2=Dict([(0,20),(1,40),(2,60),(3,80),(4,100),(5,0)])
# Out:
# Dict{Int64, Int64} with 6 entries:
#   0 => 20
#   4 => 100
#   5 => 0
#   2 => 60
#   3 => 80
#   1 => 40

# %%
ln1=Dict(758592 => "Anand" , 596235 => "Arasu" , 975179 => "Asawa" , 739244 => "Barbashov" , 408620 => "Beesley" , 524203 => "Bienert" , 767173 => "Bobyn" , 329294 => "Boivin" , 855762 => "Brown" , 782903 => "Cader" , 685939 => "Chambers" , 829577 => "Chen" , 734042 => "Coutinho" , 670452 => "Dannhauer" , 252398 => "Daryani" , 120912 => "Eng" , 653801 => "Galang" , 601465 => "Gan" , 813434 => "Ghosh" , 427093 => "Gulaty" , 629220 => "Gupta" , 300556 => "Halme" , 302588 => "Hayes" , 599647 => "Hirose" , 591716 => "Hora" , 962740 => "Huang" , 437672 => "Hughes" , 251974 => "Imura" , 262192 => "Indic" , 844462 => "Johal" , 473266 => "Karimi" , 152692 => "Kaur" , 451220 => "Kennedy" , 274293 => "Kutluay" , 573322 => "Lacroix" , 217056 => "Lee" , 637153 => "Li" , 551028 => "Lin" , 171109 => "Lister" , 553009 => "Litt" , 104891 => "Liu" , 424276 => "Logue" , 284514 => "Ma" , 104618 => "Ma" , 326959 => "Mann-Kuefler" , 772634 => "Maxwell" , 479675 => "Meyer" , 519678 => "Mishra" , 327137 => "Mitchell Serpas" , 620063 => "Morales" , 273825 => "Muglich" , 374526 => "Northeast" , 781936 => "Noury" , 805101 => "Penner" , 722106 => "Peres Schneider" , 520944 => "Phillips" , 133826 => "Poon" , 734739 => "Qian" , 631199 => "Qiu" , 935063 => "Roboobi" , 911815 => "Schmitter" , 904274 => "Sharma" , 624831 => "Sharma" , 471871 => "Sioui" , 109220 => "Smith" , 171477 => "Stampliaka" , 136541 => "Stumborg" , 605009 => "Tabenkin" , 837888 => "Uppal" , 117939 => "Urban" , 464214 => "Wan" , 331329 => "Wang" , 507497 => "Wong" , 227667 => "Yang" , 769815 => "Ye" , 230494 => "Zeng" , 488081 => "Zhang" , 214934 => "Zhao" , 539865 => "Zhou" , 377532 => "Zurkovic" , 529445 => "Chang" , 586981 => "Dhillon" , 159842 => "Duff" , 854333 => "Kohan" , 655715 => "Lee" , 123875 => "Morinaka" , 373901 => "Peiro" , 480843 => "Wang" , 599697 => "Wilson" , 868366 => "Zhu" , 374400 => "Cuddington")
# Out:
# Dict{Int64, String} with 91 entries:
#   670452 => "Dannhauer"
#   844462 => "Johal"
#   217056 => "Lee"
#   653801 => "Galang"
#   591716 => "Hora"
#   631199 => "Qiu"
#   227667 => "Yang"
#   377532 => "Zurkovic"
#   104891 => "Liu"
#   326959 => "Mann-Kuefler"
#   734042 => "Coutinho"
#   136541 => "Stumborg"
#   123875 => "Morinaka"
#   273825 => "Muglich"
#   758592 => "Anand"
#   519678 => "Mishra"
#   868366 => "Zhu"
#   601465 => "Gan"
#   464214 => "Wan"
#   599697 => "Wilson"
#   551028 => "Lin"
#   171109 => "Lister"
#   437672 => "Hughes"
#   252398 => "Daryani"
#   331329 => "Wang"
#   ⋮      => ⋮

# %%
fn1=Dict(758592 => "Shaurya Veer", 596235 => "Menaka", 975179 => "Vaidehi", 739244 => "Yury", 408620 => "Tabby", 524203 => "Bella", 767173 => "Alex ()", 329294 => "Jack Thomas", 855762 => "Maya", 782903 => "Sarah", 685939 => "Colby", 829577 => "Emily", 734042 => "Annika", 670452 => "Alex ()", 252398 => "Khushi", 120912 => "Julie", 653801 => "Ryland", 601465 => "Ziyi", 813434 => "Anandita ()", 427093 => "Nandika", 629220 => "Saujas", 300556 => "Nick", 302588 => "Kevin", 599647 => "Tomoya", 591716 => "Advay", 962740 => "Andrew", 437672 => "Bryce", 251974 => "Dennis", 262192 => "Stefan", 844462 => "Kajol", 473266 => "Andromeda", 152692 => "Kirin", 451220 => "Matthew", 274293 => "Gulsen", 573322 => "Anila", 217056 => "Daniel", 637153 => "Ben", 551028 => "Jiarui", 171109 => "Graeme", 553009 => "Karman", 104891 => "Ryan", 424276 => "Jamie", 284514 => "Gary", 104618 => "Jenny", 326959 => "Alex", 772634 => "Alex", 479675 => "Sam", 519678 => "Vivan", 327137 => "Joshua", 620063 => "Marissa", 273825 => "Shervin", 374526 => "Imani", 781936 => "Malak", 805101 => "Madeleine", 722106 => "Fabio", 520944 => "Natalie", 133826 => "Owen", 734739 => "Yi", 631199 => "Dean", 935063 => "Khoobun", 911815 => "Cameron", 904274 => "Serena ()", 624831 => "Vishwa", 471871 => "Amanda ()", 109220 => "Makyla", 171477 => "Caroline", 136541 => "Esme", 605009 => "Gal", 837888 => "Jacquelyn", 117939 => "Jessica ()", 464214 => "Tianrun", 331329 => "Wensen ()", 507497 => "Hui", 227667 => "Trafaline", 769815 => "Ryan", 230494 => "Sabrina", 488081 => "Jiaxin", 214934 => "Curtis", 539865 => "Xinran", 377532 => "Nicholas", 529445 => "Ian", 586981 => "Simran", 159842 => "Allison", 854333 => "Anthony", 655715 => "Spencer", 123875 => "Kate", 373901 => "Milad", 480843 => "Sabrina", 599697 => "Isabel", 868366 => "Kaida", 374400 => "Eero")
# Out:
# Dict{Int64, String} with 91 entries:
#   670452 => "Alex ()"
#   844462 => "Kajol"
#   217056 => "Daniel"
#   653801 => "Ryland"
#   591716 => "Advay"
#   631199 => "Dean"
#   227667 => "Trafaline"
#   377532 => "Nicholas"
#   104891 => "Ryan"
#   326959 => "Alex"
#   734042 => "Annika"
#   136541 => "Esme"
#   123875 => "Kate"
#   273825 => "Shervin"
#   758592 => "Shaurya Veer"
#   519678 => "Vivan"
#   868366 => "Kaida"
#   601465 => "Ziyi"
#   464214 => "Tianrun"
#   599697 => "Isabel"
#   551028 => "Jiarui"
#   171109 => "Graeme"
#   437672 => "Bryce"
#   252398 => "Khushi"
#   331329 => "Wensen ()"
#   ⋮      => ⋮

# %%
function k1(x)
       d1[x]
       end
function k2(x)
       d2[x]
       end
function k3(x)
       ln1[x]
       end
function k4(x)
       fn1[x]
       end
# Out:
# k4 (generic function with 1 method)

# %%
t1=select(q1,:ast => ByRow(k1),:sdc,:sc => ByRow(k2))
# Out:
# 1729×3 DataFrame
#   Row │ ast_k1  sdc     sc_k2
#       │ String  Int64   Int64
# ──────┼───────────────────────
#     1 │ fvxa    104618     80
#     2 │ fvxa    104891      0
#     3 │ fvxa    109220      0
#     4 │ fvxa    117939      0
#     5 │ fvxa    120912      0
#     6 │ fvxa    123875     80
#     7 │ fvxa    133826     60
#     8 │ fvxa    136541    100
#     9 │ fvxa    152692    100
#    10 │ fvxa    159842      0
#    11 │ fvxa    171109     60
#   ⋮   │   ⋮       ⋮       ⋮
#  1720 │ goag    586981      0
#  1721 │ goag    159842      0
#  1722 │ goag    854333    100
#  1723 │ goag    655715     80
#  1724 │ goag    123875     80
#  1725 │ goag    373901      0
#  1726 │ goag    480843     60
#  1727 │ goag    599697      0
#  1728 │ goag    868366      0
#  1729 │ goag    374400    100
#              1708 rows omitted

# %%
CSV.write("./csv/paperquiz.csv",t1)
# Out:
# "./csv/paperquiz.csv"

# %%
t2=select(q1,:sdc,:sc => ByRow(k2),:fn,:ln)
# Out:
# 1729×4 DataFrame
#   Row │ sdc     sc_k2  fn          ln
#       │ Int64   Int64  String15    String15
# ──────┼───────────────────────────────────────
#     1 │ 104618     80  Jenny       Ma
#     2 │ 104891      0  Ryan        Liu
#     3 │ 109220      0  Makyla      Smith
#     4 │ 117939      0  Jessica ()  Urban
#     5 │ 120912      0  Julie       Eng
#     6 │ 123875     80  Kate        Morinaka
#     7 │ 133826     60  Owen        Poon
#     8 │ 136541    100  Esme        Stumborg
#     9 │ 152692    100  Kirin       Kaur
#    10 │ 159842      0  Allison     Duff
#    11 │ 171109     60  Graeme      Lister
#   ⋮   │   ⋮       ⋮        ⋮           ⋮
#  1720 │ 586981      0  Simran      Dhillon
#  1721 │ 159842      0  Allison     Duff
#  1722 │ 854333    100  Anthony     Kohan
#  1723 │ 655715     80  Spencer     Lee
#  1724 │ 123875     80  Kate        Morinaka
#  1725 │ 373901      0  Milad       Peiro
#  1726 │ 480843     60  Sabrina     Wang
# ...

# %%
q3g=groupby(t2,:sdc)
# Out:
# GroupedDataFrame with 91 groups based on key: sdc
# First Group (19 rows): sdc = 104618
#  Row │ sdc     sc_k2  fn        ln
#      │ Int64   Int64  String15  String15
# ─────┼───────────────────────────────────
#    1 │ 104618     80  Jenny     Ma
#    2 │ 104618     80  Jenny     Ma
#    3 │ 104618     60  Jenny     Ma
#    4 │ 104618    100  Jenny     Ma
#    5 │ 104618     80  Jenny     Ma
#    6 │ 104618     40  Jenny     Ma
#    7 │ 104618     60  Jenny     Ma
#    8 │ 104618     40  Jenny     Ma
#    9 │ 104618     80  Jenny     Ma
#   10 │ 104618    100  Jenny     Ma
#   11 │ 104618     60  Jenny     Ma
#   12 │ 104618     40  Jenny     Ma
#   13 │ 104618    100  Jenny     Ma
#   14 │ 104618     60  Jenny     Ma
#   15 │ 104618     80  Jenny     Ma
#   16 │ 104618     80  Jenny     Ma
#   17 │ 104618     60  Jenny     Ma
#   18 │ 104618     20  Jenny     Ma
#   19 │ 104618     60  Jenny     Ma
# ⋮
# Last Group (19 rows): sdc = 975179
#  Row │ sdc     sc_k2  fn        ln
# ...

# %%
t3=sort(combine(q3g,:sc_k2 => mean),:sc_k2_mean,rev=true)
# Out:
# 91×2 DataFrame
#  Row │ sdc     sc_k2_mean
#      │ Int64   Float64
# ─────┼────────────────────
#    1 │ 507497     98.9474
#    2 │ 854333     98.9474
#    3 │ 300556     95.7895
#    4 │ 605009     95.7895
#    5 │ 374400     90.5263
#    6 │ 734042     90.5263
#    7 │ 377532     88.4211
#    8 │ 573322     88.4211
#    9 │ 734739     88.4211
#   10 │ 767173     86.3158
#   11 │ 488081     85.2632
#   ⋮  │   ⋮         ⋮
#   82 │ 553009      0.0
#   83 │ 599647      0.0
#   84 │ 599697      0.0
#   85 │ 601465      0.0
#   86 │ 620063      0.0
#   87 │ 624831      0.0
#   88 │ 637153      0.0
#   89 │ 739244      0.0
#   90 │ 813434      0.0
#   91 │ 868366      0.0
#            70 rows omitted

# %%
t4=hcat(DataFrame(ast=repeat(["bjle"],91)),combine(q3g,:sc_k2 => mean))
# Out:
# 91×3 DataFrame
#  Row │ ast     sdc     sc_k2_mean
#      │ String  Int64   Float64
# ─────┼────────────────────────────
#    1 │ bjle    104618    67.3684
#    2 │ bjle    104891     0.0
#    3 │ bjle    109220    27.3684
#    4 │ bjle    117939     0.0
#    5 │ bjle    120912     0.0
#    6 │ bjle    123875    66.3158
#    7 │ bjle    133826    60.0
#    8 │ bjle    136541    70.5263
#    9 │ bjle    152692    65.2632
#   10 │ bjle    159842     0.0
#   11 │ bjle    171109    76.8421
#   ⋮  │   ⋮       ⋮         ⋮
#   82 │ bjle    837888    44.2105
#   83 │ bjle    844462    64.2105
#   84 │ bjle    854333    98.9474
#   85 │ bjle    855762    25.2632
#   86 │ bjle    868366     0.0
#   87 │ bjle    904274    56.8421
#   88 │ bjle    911815    60.0
#   89 │ bjle    935063     6.31579
#   90 │ bjle    962740    45.2632
#   91 │ bjle    975179    52.6316
#                    70 rows omitted

# %%
function k5(x)
    floor((100*x)+0.5)/100
end
# Out:
# k5 (generic function with 1 method)

# %%
t5=select(t4,:ast,:sdc,:sc_k2_mean => ByRow(k5))
# Out:
# 91×3 DataFrame
#  Row │ ast     sdc     sc_k2_mean_k5
#      │ String  Int64   Float64
# ─────┼───────────────────────────────
#    1 │ bjle    104618          67.37
#    2 │ bjle    104891           0.0
#    3 │ bjle    109220          27.37
#    4 │ bjle    117939           0.0
#    5 │ bjle    120912           0.0
#    6 │ bjle    123875          66.32
#    7 │ bjle    133826          60.0
#    8 │ bjle    136541          70.53
#    9 │ bjle    152692          65.26
#   10 │ bjle    159842           0.0
#   11 │ bjle    171109          76.84
#   ⋮  │   ⋮       ⋮           ⋮
#   82 │ bjle    837888          44.21
#   83 │ bjle    844462          64.21
#   84 │ bjle    854333          98.95
#   85 │ bjle    855762          25.26
#   86 │ bjle    868366           0.0
#   87 │ bjle    904274          56.84
#   88 │ bjle    911815          60.0
#   89 │ bjle    935063           6.32
#   90 │ bjle    962740          45.26
#   91 │ bjle    975179          52.63
# ...

# %%
CSV.write("./csv/zaperquiz.csv",t5)
# Out:
# "./csv/zaperquiz.csv"
