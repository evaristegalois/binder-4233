# %%
*(600000,0.0289,/(1,12))
# Out:
# 1445.0

# %%
+(*(//(2,3),-(64,1)),3)
# Out:
# 45//1

# %%
^(17,3)
# Out:
# 4913

# %%
sqrt(+(9,^(-(*(/(2,3),sqrt(4913)),*(/(4,3),sqrt(2))),2)))
# Out:
# 44.94315061472669

# %%
^(sec(/(pi,4)),2)
# Out:
# 1.9999999999999996

# %%
x1=/(4,^(8,/(1,3)))
# Out:
# 2.0

# %%
y1=/(4,^(8,/(1,3)))
# Out:
# 2.0

# %%
z1=/(2,^(8,/(1,3)))
# Out:
# 1.0

# %%
*(x1,y1,z1)
# Out:
# 4.0

# %%
sqrt(3)
# Out:
# 1.7320508075688772

# %%
*(10,log(2))
# Out:
# 6.931471805599453

# %%
*(2,exp(/(*(2,pi),-10)))
# Out:
# 1.0669761821822066

# %%
*(2,pi)
# Out:
# 6.283185307179586

# %%
# calculations in Schmierbuch 3650

# %%
R1=*(2,+(*(2,pi),*(5,-(exp(*(/(-2,5),pi)),1))))
# Out:
# 5.412466047719465

# %%
+(R1,*(/(2,3),R1),pi)
# Out:
# 12.1623693997889

# %%
*(4,pi)
# Out:
# 12.566370614359172

# %%
using SymPy

# %%
@vars x
# Out:
# (x,)

# %%
SymPy.integrate(-(1,^(SymPy.cos(x),2)))
# Out:
# x   sin(x)⋅cos(x)
# ─ - ─────────────
# 2         2

# %%
SymPy.integrate(^(SymPy.cos(x),2))
# Out:
# x   sin(x)⋅cos(x)
# ─ + ─────────────
# 2         2

# %%
-(375,39.88)
# Out:
# 335.12

# %%
-(1,/(-(cos(/(180,pi)),1),-(-sin(/(180,pi)),1)))
# Out:
# 0.8414159841433891

# %%
using CSV, DataFrames, Statistics, FreqTables

# %%
a1=DataFrame(CSV.File("./syltab.csv"))
# Out:
# ┌ Warning: thread = 1 warning: parsed expected 4 columns, but didn't reach end of line around data row: 3. Parsing extra columns and widening final columnset
# └ @ CSV /srv/julia/pkg/packages/CSV/jFiCn/src/file.jl:579
# ┌ Warning: thread = 1 warning: only found 4 / 6 columns around data row: 4. Filling remaining columns with `missing`
# └ @ CSV /srv/julia/pkg/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 4 / 6 columns around data row: 5. Filling remaining columns with `missing`
# └ @ CSV /srv/julia/pkg/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 4 / 6 columns around data row: 6. Filling remaining columns with `missing`
# └ @ CSV /srv/julia/pkg/packages/CSV/jFiCn/src/file.jl:578
# ┌ Warning: thread = 1 warning: only found 4 / 6 columns around data row: 1. Filling remaining columns with `missing`
# └ @ CSV /srv/julia/pkg/packages/CSV/jFiCn/src/file.jl:578
# ...

# %%
a2=DataFrame(CSV.File("./finred.csv"))
# Out:
# 19×1 DataFrame
#  Row │ Acronym
#      │ String3
# ─────┼─────────
#    1 │ KVH
#    2 │ EKS
#    3 │ GSA
#    4 │ MSN
#    5 │ JPS
#    6 │ CTA
#    7 │ EAG
#    8 │ HOL
#    9 │ DBA
#   10 │ DOS
#   11 │ CTH
#   12 │ POP
#   13 │ MAD
#   14 │ MFB
#   15 │ BAR
#   16 │ BUT
#   17 │ VGL
#   18 │ OMA
#   19 │ OMB

# %%
a3=innerjoin(a1,a2,on=:Acronym)
# Out:
# 19×6 DataFrame
#  Row │ Acronym  Author                         Title                           ⋯
#      │ String3  String31                       String                          ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ BAR      Roland Barthes                 The Death of the Author         ⋯
#    2 │ BUT      Judith Butler                  Identity
#    3 │ CTA      Charles Taylor                 What Is Human Agency?
#    4 │ CTH      Chris Thornhill                Two Rival Critiques of Metaphys
#    5 │ DBA      John Dewey and Arthur Bentley  Interaction and Transaction     ⋯
#    6 │ DOS      Fyodor Dostoyevsky             Underground
#    7 │ EAG      Terry Eagleton                 The Rise of English and PHRT
#    8 │ EKS      Eve Kosofsky Sedgwick          Paranoid Reading and Reparative
#    9 │ GSA      Galen Strawson                 Against Narrativity             ⋯
# ...

# %%
CSV.write("./csv/finauth.csv",a3)
# Out:
# "./csv/finauth.csv"
