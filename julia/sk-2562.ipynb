# %%
*(600000,0.0289,/(1,12))
# Out:
# 1445.0

# %%
+(*(//(2,3),-(64,1)),3)
# Out:
# 45//1

# %%
^(17,3)
# Out:
# 4913

# %%
sqrt(+(9,^(-(*(/(2,3),sqrt(4913)),*(/(4,3),sqrt(2))),2)))
# Out:
# 44.94315061472669

# %%
^(sec(/(pi,4)),2)
# Out:
# 1.9999999999999996

# %%
x1=/(4,^(8,/(1,3)))
# Out:
# 2.0

# %%
y1=/(4,^(8,/(1,3)))
# Out:
# 2.0

# %%
z1=/(2,^(8,/(1,3)))
# Out:
# 1.0

# %%
*(x1,y1,z1)
# Out:
# 4.0

# %%
sqrt(3)
# Out:
# 1.7320508075688772

# %%
*(10,log(2))
# Out:
# 6.931471805599453

# %%
*(2,exp(/(*(2,pi),-10)))
# Out:
# 1.0669761821822066

# %%
*(2,pi)
# Out:
# 6.283185307179586

# %%
# calculations in Schmierbuch 3650

# %%
R1=*(2,+(*(2,pi),*(5,-(exp(*(/(-2,5),pi)),1))))
# Out:
# 5.412466047719465

# %%
+(R1,*(/(2,3),R1),pi)
# Out:
# 12.1623693997889

# %%
*(4,pi)
# Out:
# 12.566370614359172

# %%
using SymPy

# %%
@vars x
# Out:
# (x,)

# %%
SymPy.integrate(-(1,^(SymPy.cos(x),2)))
# Out:
# x   sin(x)⋅cos(x)
# ─ - ─────────────
# 2         2

# %%
SymPy.integrate(^(SymPy.cos(x),2))
# Out:
# x   sin(x)⋅cos(x)
# ─ + ─────────────
# 2         2

# %%
-(375,39.88)
# Out:
# 335.12

# %%
-(1,/(-(cos(/(180,pi)),1),-(-sin(/(180,pi)),1)))
# Out:
# 0.8414159841433891

# %%
using CSV
using DataFrames
using DataFramesMeta
using Statistics
using FreqTables

# %%
e1=DataFrame(CSV.File("./csv/e1.csv"))
# Out:
# 91×5 DataFrame
#  Row │ sc     sdc     sno       ln          fn
#      │ Int64  Int64   Int64     String15    String15
# ─────┼──────────────────────────────────────────────────
#    1 │    89  104618  53639084  Ma          Jenny
#    2 │     0  104891  21791843  Liu         Ryan
#    3 │    89  109220  47707195  Smith       Makyla
#    4 │     0  117939  62159470  Urban       Jessica ()
#    5 │     0  120912  46027488  Eng         Julie
#    6 │    91  123875  47130190  Morinaka    Kate
#    7 │    90  133826  32998205  Poon        Owen
#    8 │    93  136541  55693444  Stumborg    Esme
#    9 │    90  152692  81004772  Kaur        Kirin
#   10 │     0  159842  56710692  Duff        Allison
#   11 │    88  171109  59219527  Lister      Graeme
#   ⋮  │   ⋮      ⋮        ⋮          ⋮            ⋮
#   82 │    97  837888  85615573  Uppal       Jacquelyn
#   83 │    91  844462  52491586  Johal       Kajol
#   84 │    90  854333  38426516  Kohan       Anthony
# ...

# %%
a1=DataFrame(CSV.File("./csv/asts.csv"))
# Out:
# 24×2 DataFrame
#  Row │ asts     tla
#      │ String7  String3
# ─────┼──────────────────
#    1 │ fvxa     KVH
#    2 │ yqoq     EKS
#    3 │ fvxa     GSA
#    4 │ yqoq     MSN
#    5 │ cdlm     JPS
#    6 │ eion     CTA
#    7 │ qmvi     EAG
#    8 │ veiy     HOL
#    9 │ oexk     DBA
#   10 │ tfov     DOS
#   11 │ dduv     HGG
#   ⋮  │    ⋮        ⋮
#   15 │ lett     MFB
#   16 │ xfqk     CTC
#   17 │ prif     MFD
#   18 │ bosg     BUT
#   19 │ xega     VGL
#   20 │ obye     BAR
#   21 │ xxol     OMA
#   22 │ goag     OMB
#   23 │ kynz     KOL
#   24 │ aeyb     RSB
#           3 rows omitted

# %%
q1=DataFrame(CSV.File("./csv/quiz.csv"))
# Out:
# 910×6 DataFrame
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼──────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     5  KVH      104891  21791843  Liu         Ryan
#    3 │     5  KVH      109220  47707195  Smith       Makyla
#    4 │     5  KVH      117939  62159470  Urban       Jessica ()
#    5 │     5  KVH      120912  46027488  Eng         Julie
#    6 │     3  KVH      123875  47130190  Morinaka    Kate
#    7 │     2  KVH      133826  32998205  Poon        Owen
#    8 │     4  KVH      136541  55693444  Stumborg    Esme
#    9 │     4  KVH      152692  81004772  Kaur        Kirin
#   10 │     5  KVH      159842  56710692  Duff        Allison
#   11 │     2  KVH      171109  59219527  Lister      Graeme
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
# ...

# %%
freqtable(q1[:,:sc])
# Out:
# 6-element Named Vector{Int64}
# Dim1  │
# ──────┼────
# 0     │  24
# 1     │  64
# 2     │ 115
# 3     │ 171
# 4     │ 229
# 5     │ 307

# %%
q1g=groupby(q1,:ast)
# Out:
# GroupedDataFrame with 10 groups based on key: ast
# First Group (91 rows): ast = "KVH"
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼───────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     5  KVH      104891  21791843  Liu         Ryan
#    3 │     5  KVH      109220  47707195  Smith       Makyla
#    4 │     5  KVH      117939  62159470  Urban       Jessica ()
#    5 │     5  KVH      120912  46027488  Eng         Julie
#    6 │     3  KVH      123875  47130190  Morinaka    Kate
#    7 │     2  KVH      133826  32998205  Poon        Owen
#    8 │     4  KVH      136541  55693444  Stumborg    Esme
#    9 │     4  KVH      152692  81004772  Kaur        Kirin
#   10 │     5  KVH      159842  56710692  Duff        Allison
#   11 │     2  KVH      171109  59219527  Lister      Graeme
# ...

# %%
show(combine(q1g,:sc => freqtable),allrows=true)
# Out:
# 57×2 DataFrame
#  Row │ ast      sc_freqtable
#      │ String3  Int64
# ─────┼───────────────────────
#    1 │ KVH                 1
#    2 │ KVH                11
#    3 │ KVH                16
#    4 │ KVH                16
#    5 │ KVH                25
#    6 │ KVH                22
#    7 │ EKS                 5
#    8 │ EKS                 6
#    9 │ EKS                29
#   10 │ EKS                28
#   11 │ EKS                23
#   12 │ GSA                 3
#   13 │ GSA                 8
#   14 │ GSA                14
#   15 │ GSA                29
#   16 │ GSA                14
#   17 │ GSA                23
#   18 │ MSN                 2
#   19 │ MSN                 9
#   20 │ MSN                17
#   21 │ MSN                18
#   22 │ MSN                20
#   23 │ MSN                25
#   24 │ JPS                 2
#   25 │ JPS                 4
#   26 │ JPS                18
#   27 │ JPS                14
#   28 │ JPS                25
# ...

# %%
q2=q1
# Out:
# 910×6 DataFrame
#  Row │ sc     ast      sdc     sno       ln          fn
#      │ Int64  String3  Int64   Int64     String15    String15
# ─────┼──────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny
#    2 │     5  KVH      104891  21791843  Liu         Ryan
#    3 │     5  KVH      109220  47707195  Smith       Makyla
#    4 │     5  KVH      117939  62159470  Urban       Jessica ()
#    5 │     5  KVH      120912  46027488  Eng         Julie
#    6 │     3  KVH      123875  47130190  Morinaka    Kate
#    7 │     2  KVH      133826  32998205  Poon        Owen
#    8 │     4  KVH      136541  55693444  Stumborg    Esme
#    9 │     4  KVH      152692  81004772  Kaur        Kirin
#   10 │     5  KVH      159842  56710692  Duff        Allison
#   11 │     2  KVH      171109  59219527  Lister      Graeme
#   ⋮  │   ⋮       ⋮       ⋮        ⋮          ⋮           ⋮
# ...

# %%
transform(q2,1,:ast => (ast -> ifelse(ast == "KVH","abcd","efgh")))
# Out:
# 910×7 DataFrame
#  Row │ sc     ast      sdc     sno       ln          fn          ast_function
#      │ Int64  String3  Int64   Int64     String15    String15    String
# ─────┼────────────────────────────────────────────────────────────────────────
#    1 │     3  KVH      104618  53639084  Ma          Jenny       efgh
#    2 │     5  KVH      104891  21791843  Liu         Ryan        efgh
#    3 │     5  KVH      109220  47707195  Smith       Makyla      efgh
#    4 │     5  KVH      117939  62159470  Urban       Jessica ()  efgh
#    5 │     5  KVH      120912  46027488  Eng         Julie       efgh
#    6 │     3  KVH      123875  47130190  Morinaka    Kate        efgh
#    7 │     2  KVH      133826  32998205  Poon        Owen        efgh
#    8 │     4  KVH      136541  55693444  Stumborg    Esme        efgh
#    9 │     4  KVH      152692  81004772  Kaur        Kirin       efgh
#   10 │     5  KVH      159842  56710692  Duff        Allison     efgh
# ...

# %%
q2[:,[:ast]].=ifelse.(q2[!,[:ast]].=="KVH","abc","efg")
# Out:
# 910×1 SubDataFrame
#  Row │ ast
#      │ String3
# ─────┼─────────
#    1 │ abc
#    2 │ abc
#    3 │ abc
#    4 │ abc
#    5 │ abc
#    6 │ abc
#    7 │ abc
#    8 │ abc
#    9 │ abc
#   10 │ abc
#   11 │ abc
#   ⋮  │    ⋮
#  901 │ efg
#  902 │ efg
#  903 │ efg
#  904 │ efg
#  905 │ efg
#  906 │ efg
#  907 │ efg
#  908 │ efg
#  909 │ efg
#  910 │ efg
# 889 rows omitted

# %%
insertcols!(q2,1,:astid => ifelse.(q2[!,[:ast]].=="KVH","abcd","efgh"))
# Out:
# 910×7 DataFrame
#  Row │ astid            sc     ast      sdc     sno       ln          fn       ⋯
#      │ DataFrame        Int64  String3  Int64   Int64     String15    String15 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 910×1 DataFrame      3  KVH      104618  53639084  Ma          Jenny    ⋯
#    2 │ 910×1 DataFrame      5  KVH      104891  21791843  Liu         Ryan
#    3 │ 910×1 DataFrame      5  KVH      109220  47707195  Smith       Makyla
#    4 │ 910×1 DataFrame      5  KVH      117939  62159470  Urban       Jessica
#    5 │ 910×1 DataFrame      5  KVH      120912  46027488  Eng         Julie    ⋯
#    6 │ 910×1 DataFrame      3  KVH      123875  47130190  Morinaka    Kate
#    7 │ 910×1 DataFrame      2  KVH      133826  32998205  Poon        Owen
#    8 │ 910×1 DataFrame      4  KVH      136541  55693444  Stumborg    Esme
#    9 │ 910×1 DataFrame      4  KVH      152692  81004772  Kaur        Kirin    ⋯
# ...

# %%
q3=hcat(ifelse.(q2[!,[:ast]].=="KVH","abcd",ifelse.(q2[!,[:ast]].=="EKS","efgh","ijkl")),rename(q2,:ast=>:astid))
# Out:
# 910×7 DataFrame
#  Row │ ast     sc     astid    sdc     sno       ln          fn
#      │ String  Int64  String3  Int64   Int64     String15    String15
# ─────┼──────────────────────────────────────────────────────────────────
#    1 │ abcd        3  KVH      104618  53639084  Ma          Jenny
#    2 │ abcd        5  KVH      104891  21791843  Liu         Ryan
#    3 │ abcd        5  KVH      109220  47707195  Smith       Makyla
#    4 │ abcd        5  KVH      117939  62159470  Urban       Jessica ()
#    5 │ abcd        5  KVH      120912  46027488  Eng         Julie
#    6 │ abcd        3  KVH      123875  47130190  Morinaka    Kate
#    7 │ abcd        2  KVH      133826  32998205  Poon        Owen
#    8 │ abcd        4  KVH      136541  55693444  Stumborg    Esme
#    9 │ abcd        4  KVH      152692  81004772  Kaur        Kirin
#   10 │ abcd        5  KVH      159842  56710692  Duff        Allison
#   11 │ abcd        2  KVH      171109  59219527  Lister      Graeme
# ...

# %%
q3=hcat(
ifelse.(q2[!,[:ast]].=="KVH","fvxa",
ifelse.(q2[!,[:ast]].=="EKS","yqoq",
ifelse.(q2[!,[:ast]].=="GSA","fvxa",
ifelse.(q2[!,[:ast]].=="MSN","yqoq",
ifelse.(q2[!,[:ast]].=="JPS","cdlm",
ifelse.(q2[!,[:ast]].=="CTA","eion",
ifelse.(q2[!,[:ast]].=="EAG","qmvi",
ifelse.(q2[!,[:ast]].=="HOL","veiy",
ifelse.(q2[!,[:ast]].=="DBA","oexk",
"tfov"))))))))),rename(q2,:ast=>:astid))
