# %%
using CSV, DataFrames, Statistics, FreqTables

# %%
a1=DataFrame(CSV.File("./csv/allowance.csv"))
# Out:
# 1526×4 DataFrame
#   Row │ alldate     username   amount   category
#       │ Date        String15   Float64  String
# ──────┼─────────────────────────────────────────────────
#     1 │ 2014-08-18  anderson       3.0  allowance
#     2 │ 2014-08-18  evelyn         2.0  allowance
#     3 │ 2014-08-25  anderson       3.0  allowance
#     4 │ 2014-08-25  evelyn         2.0  allowance
#     5 │ 2014-09-01  anderson       3.0  allowance
#     6 │ 2014-09-01  evelyn         2.0  allowance
#     7 │ 2014-09-08  anderson       3.0  allowance
#     8 │ 2014-09-08  evelyn         2.0  allowance
#     9 │ 2014-09-15  anderson       3.0  allowance
#    10 │ 2014-09-15  evelyn         2.0  allowance
#    11 │ 2014-09-22  anderson       3.0  allowance
#   ⋮   │     ⋮           ⋮         ⋮            ⋮
#  1517 │ 2022-05-16  josephine      3.0  allowance
#  1518 │ 2022-05-23  evelyn         5.0  allowance
#  1519 │ 2022-05-23  josephine      3.0  allowance
# ...

# %%
a2=groupby(a1,:username)
# Out:
# GroupedDataFrame with 3 groups based on key: username
# First Group (535 rows): username = "anderson"
#  Row │ alldate     username  amount   category
#      │ Date        String15  Float64  String
# ─────┼──────────────────────────────────────────────────────────────────
#    1 │ 2014-08-18  anderson     3.0   allowance
#    2 │ 2014-08-25  anderson     3.0   allowance
#    3 │ 2014-09-01  anderson     3.0   allowance
#    4 │ 2014-09-08  anderson     3.0   allowance
#    5 │ 2014-09-15  anderson     3.0   allowance
#    6 │ 2014-09-22  anderson     3.0   allowance
#    7 │ 2014-09-29  anderson     3.0   allowance
#    8 │ 2014-10-06  anderson     3.0   allowance
#    9 │ 2014-10-13  anderson     3.0   allowance
#   10 │ 2014-10-15  anderson   -16.8   gem
#   11 │ 2014-10-20  anderson     3.0   allowance
#   ⋮  │     ⋮          ⋮         ⋮                     ⋮
#  525 │ 2022-01-15  anderson   -22.4   Best Buy headset
# ...

# %%
combine(a2,:amount => sum)
# Out:
# 3×2 DataFrame
#  Row │ username   amount_sum
#      │ String15   Float64
# ─────┼───────────────────────
#    1 │ anderson      1268.08
#    2 │ evelyn         568.71
#    3 │ josephine      341.72
