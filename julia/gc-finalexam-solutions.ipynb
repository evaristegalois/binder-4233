# %% [markdown]
# <h2>Final Exam</h2>

# %% [markdown]
# <h3>Question 1</h3>

# %% [markdown]
# Find the length of the secant line segment from $x=1$ to
# $x=4$ for
# \begin{equation}
#   \label{eq:jcprlsjk}
#   f(x)=\frac{2}{3}\left(x^2+1\right)^{\frac{3}{2}}\notag
# \end{equation}
# Then find the arc length of the curve between $x=1$ and
# $x=4$. The length of the secant line segment should be a good
# approximation of the arc length.

# %% [markdown]
# <img src="./diagrams/fe-01.png" width="77%" height="77%">

# %%
sqrt(+(9,^(-(*(/(2,3),sqrt(4913)),*(/(4,3),sqrt(2))),2)))
# Out:
# 44.94315061472669

# %% [markdown]
# <h3>Question 2</h3>

# %% [markdown]
# <font color="red">2 points for y', more points only if product rule applied for y''</font>

# %% [markdown]
# Find $y''$ and simplify it as much as possible.
# \begin{equation}
#   \label{eq:hnchxfnu}
#   y=\left(1+\frac{1}{x}\right)^3\notag
# \end{equation}

# %% [markdown]
# <img src="./diagrams/fe-02.png" width="77%" height="77%">

# %%
using SymPy # in above png (-2) needs to be (+6) instead

# %%
@vars x
# Out:
# (x,)

# %%
f1(x)=+(*(6,^(x,3),^(+(1,x),2)),*(6,^(x,4),+(1,x)))
# Out:
# f1 (generic function with 1 method)

# %%
f1(x)
# Out:
#    4              3        2
# 6⋅x ⋅(x + 1) + 6⋅x ⋅(x + 1)

# %%
expand(f1(x))
# Out:
#     5       4      3
# 12⋅x  + 18⋅x  + 6⋅x

# %% [markdown]
# $$
# \frac{6}{x^3}+\frac{18}{x^4}+\frac{12}{x^5}
# $$

# %% [markdown]
# <h3>Question 3</h3>

# %% [markdown]
# <font color="red">give 1.5 points if Newton's method correctly applied to f(x)=cosx with results 1.64 and 1.57</font>

# %% [markdown]
# It is evident from the diagram that the equation
# \begin{equation}
#   \label{eq:rkygyzii}
#   \cos{}x=x\notag
# \end{equation}
# has a solution between $0$ and $\frac{\pi}{2}$. Let your first guess be $x_0=1$.
# Find $x_1$ and $x_2$ using Newton's method.

# %%
f(x)=x-cos(x)
# Out:
# f (generic function with 1 method)

# %%
fp(x)=1+sin(x)
# Out:
# fp (generic function with 1 method)

# %%
x0=1
# Out:
# 1

# %%
x1=-(x0,/(f(x0),fp(x0)))
# Out:
# 0.7503638678402439

# %%
x2=-(x1,/(f(x1),fp(x1)))
# Out:
# 0.7391128909113617

# %% [markdown]
# <h3>Question 4</h3>

# %% [markdown]
# Using Taylor polynomials, identify $A,B,C,D$ in the approximation
# \begin{equation}
#   \label{eq:rrhmlqex}
#   \tan{}x\approx{}A+B\left(x-\frac{\pi}{4}\right)+C\left(x-\frac{\pi}{4}\right)^2+D\left(x-\frac{\pi}{4}\right)^3\notag
# \end{equation}

# %% [markdown]
# <img src="./diagrams/fe-03.png" width="77%" height="77%">

# %%
# note that "12" at the end should be "16"

# %% [markdown]
# Alternatively,
# $$
# f'''(x)=6\tan^2x\sec^2x+2\sec^2x
# $$

# %% [markdown]
# <h3>Question 5</h3>

# %% [markdown]
# In the diagram, the circle shown is the best circular
# approximation of the curve $y=x^2$. Find $m_{x},m_{y},r$ for the
# circle equation
# \begin{equation}
#   \label{eq:xkrfgvlz}
#   \left(x-m_x\right)^2+\left(y-m_y\right)^2=r^2\notag
# \end{equation}

# %% [markdown]
# In the particular case $y=f(x)$ where $x(t)=t$ and $y(t)=f(t)$ the formula is
# \begin{equation}
#   \label{eq:quitiexa}
#   \kappa=\|R''(s)\|=\frac{|f''(t)|}{\left(1+(f'(t))^{2}\right)^{\frac{3}{2}}}\notag
# \end{equation}
# So,
# \begin{align*}
# r&=\frac{1}{2}\\
# m_x&=0\\
# m_y&=\frac{1}{2}
# \end{align*}

# %% [markdown]
# <h3>Question 6</h3>

# %% [markdown]
# Consider the integral
# \begin{equation}
#   \label{eq:eisbbjac}
#   \int\frac{x}{\sqrt{x^2+4}}\,dx\notag
# \end{equation}
# * Solve it using the substitution $u=x^2+4$.
# * Solve it using the substitution $x=2\tan\theta$.
# Use a reference triangle to reverse the trigonometric substitution.
# Make sure the results agree and show all of your steps.

# %% [markdown]
# <img src="./diagrams/fe-04.png" width="77%" height="77%">

# %% [markdown]
# <h4>Question 7</h4>

# %% [markdown]
# <font color="red">if not lidless and all is squeaky clean give 2.5</font>

# %% [markdown]
# You make a lidless cardbord box with a volume of
# $4\,m^3$. Find the dimensions of the box that requires the least
# amount of cardboard. Setting up the equations to solve
# will give you 80\% credit for this question if you use Lagrange
# multipliers. Solving them and giving the correct full
#   sentence answer gives you the full 100\%, whether you use
# Lagrange multipliers or not.

# %% [markdown]
# <img src="./diagrams/fe-05.png" width="77%" height="77%">

# %% [markdown]
# <h1>Archive</h1>

# %% [markdown]
# <h3>Question 7</h3>

# %% [markdown]
# A fence $5$ feet tall runs parallel to a tall building at
# a distance of $2$ feet from the building. What is the length
# of the shortest ladder that will reach from the ground over the fence
# to the wall of the building? Setting up the equation to solve will
# give you 80% credit for this question. Solving it and giving a full
# sentence answer gives you the remaining 20%.

# %% [markdown]
# $$f(y)=x+y=\frac{5y}{\sqrt{y^{2}-4}}+y$$

# %% [markdown]
# $$f'(y)=\frac{5\sqrt{y^{2}-4}-\frac{5y^{2}}{\sqrt{y^{2}-4}}}{y^{2}-4}+1\Longrightarrow{}y=\pm\sqrt{20^{\frac{2}{3}}+4}$$

# %%
y=sqrt(20^(2/3)+4);print(n(y))
# Out:
# 3.37165582426213

# %%
xpy=((5*y)/sqrt(y^2-4))+y

# %%
n(xpy)
# Out:
# 9.58229895384014
