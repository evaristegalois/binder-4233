# %%
A1=matrix(QQ,[[-3,-3],[2,-8]])

# %%
A1.eigenvectors_right()
# Out:
# [(-5,
#   [
#   (1, 2/3)
#   ],
#   1),
#  (-6,
#   [
#   (1, 1)
#   ],
#   1)]

# %%
M1=matrix(QQ,[[3,1],[2,1]])

# %%
v1=matrix(QQ,[[-1],[-1]])

# %%
~M1*v1
# Out:
# [ 0]
# [-1]

# %%
A2=matrix(QQ,[[1,-1],[1,-1]])

# %%
A2.eigenvectors_right()
# Out:
# [(0,
#   [
#   (1, 1)
#   ],
#   2)]

# %%
A2^2
# Out:
# [0 0]
# [0 0]

# %%
A2*matrix(QQ,[[1],[0]])
# Out:
# [1]
# [1]

# %%
A3=matrix(QQ,[[-11,3],[3,-3]])

# %%
A3.eigenvectors_right()
# Out:
# [(-2,
#   [
#   (1, 3)
#   ],
#   1),
#  (-12,
#   [
#   (1, -1/3)
#   ],
#   1)]

# %%
M3=matrix(QQ,[[11,-3,-1,0],[1,0,11,-3],[-3,3,0,-1],[0,1,-3,3]])

# %%
v3=transpose(matrix(QQ,[[100,0,0,0]]))

# %%
~M3*v3
# Out:
# [ 332/29]
# [ 276/29]
# [ -76/29]
# [-168/29]

# %%
n(332/29)
# Out:
# 11.4482758620690

# %%
A6=matrix(QQ,[[1,-5],[1,-1]])

# %%
A6.eigenvectors_right()
# Out:
# [(-2*I, [(1, 0.2000000000000000? + 0.4000000000000000?*I)], 1),
#  (2*I, [(1, 0.2000000000000000? - 0.4000000000000000?*I)], 1)]

# %%
A=matrix(QQ,[[20,-16],[-16,20]])

# %%
A.eigenvectors_right()
# Out:
# [(36,
#   [
#   (1, -1)
#   ],
#   1),
#  (4,
#   [
#   (1, 1)
#   ],
#   1)]

# %%
B=matrix(QQ,[[0,1,0,0],[20,0,-16,0],[0,0,0,1],[-16,0,20,0]])

# %%
B.eigenvectors_right()
# Out:
# [(6,
#   [
#   (1, 6, -1, -6)
#   ],
#   1),
#  (2,
#   [
#   (1, 2, 1, 2)
#   ],
#   1),
#  (-2,
#   [
#   (1, -2, 1, -2)
#   ],
#   1),
#  (-6,
#   [
#   (1, -6, -1, 6)
#   ],
#   1)]

# %%
A1=matrix(QQ,[[-0.35,0.15],[0.15,-0.75]])

# %%
A1.eigenvectors_right()
# Out:
# [(-3/10,
#   [
#   (1, 1/3)
#   ],
#   1),
#  (-4/5,
#   [
#   (1, -3)
#   ],
#   1)]

# %%
B1=matrix(QQ,[[5,5],[-5,-3]])

# %%
B1.eigenvectors_right()
# Out:
# [(1 - 3*I, [(1, -0.8000000000000000? - 0.6000000000000000?*I)], 1),
#  (1 + 3*I, [(1, -0.8000000000000000? + 0.6000000000000000?*I)], 1)]

# %%
A1=matrix(QQ,[[-60,30],[25,-75]])

# %%
A1.eigenvectors_right()
# Out:
# [(-95.89454172900137?, [(1, -1.196484724300046?)], 1),
#  (-39.10545827099863?, [(1, 0.696484724300046?)], 1)]

# %%
1/-1.1964847
# Out:
# -0.835781686134390

# %%
A1=matrix(QQ,[[0,30],[25,-75]])

# %%
A1.eigenvectors_right()
# Out:
# [(-83.93543905251678?, [(1, -2.797847968417226?)], 1),
#  (8.93543905251678?, [(1, 0.2978479684172259?)], 1)]

# %%
plot_slope_field(6*x*(y-1)^(2/3), (x,-2,2), (y,1,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot_vector_field((sin(x),cos(y)), (x,-3,3), (y,-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
y=var('y')

# %%
x=var('x')

# %%
plot_vector_field(((-1/sqrt(x^2+y^2))*x,(-1/sqrt(x^2+y^2))*y), (x,-3,3), (y,-3,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot_vector_field((x*exp(1),x*log(y)), (x,-3,3), (y,0.5,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot_vector_field((x*log(y),-x*exp(1)), (x,-3,3), (y,0.5,2))
# Out:
# Graphics object consisting of 1 graphics primitive
